# %% [markdown]
# #### WIAA Seeding Projections
# We have the 2023-2024 WI Girls Basketball tournament seeds. This will give us a chance to see if our predictions on the weights are correct. In this notebook we will:
#
# - Use the data scraped from the WIAA website to produce winning percentages used in producing the seeds for the WIAA tournament
# - Merge the winning percentage data from the 2022-2023 and 2023-2024 seasons with the seeds from those tournaments
# - Get estimates of how percentages are weighted by running a random search of the parameter space
# - Use a grid search to see if we can nail down the exact weights
# - Use a logistic regression classifier to check to see if we can use that to project the seeds in the tournament
#
# We will start by loading in the data and calculating the winning percentages.

# %%
# import statements
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
from datetime import datetime
import string
import warnings
import re

warnings.simplefilter("ignore")

# %%
def get_results(year=2023):
    """
    get_results is a method that returns a pandas DataFrame with every teams':
    - Team (name)
    - Enrollment
    - Website from the WIAA website that we pulled every teams' results from
    - A list of the Teams each Team played during the season
    - A list of the results from each game played - these will align with the order of teams listed
    - A list of dates each Team played - again, this will align with the list of teams played in order

    year: an int, this should be the year that begins each season (e.g. 2023 is for 2023-24 season); only
          allowable values for now are 2021 through 2023

    returns a pandas DataFrame - results
    """
    # Check year condition - if outside of allowable range - return an empty DataFrame
    if int(year) < 2021 or int(year) > 2023:
        results = pd.DataFrame()
    # If year in range of 2021 to 2023
    else:
        results = pd.read_csv(f"/Users/edebroux/Documents/GHS Basketball/gibraltar_basketball/wiaaWebscrape/wiaa{year}.csv", header=None).rename(columns={
            0: "Team",
            1: "Enrollment",
            2: "Website",
            3: "Teams_Played",
            4: "Scores",
            5: "Results",
            6: "Dates"
        }).drop(labels="Scores", axis=1).sort_values(by="Team").reset_index(drop=True)
        # Fix some names for consistency
        results["Team"] = results["Team"].str.replace("McDonell Central Catholic", "McDonell Catholic")
        results["Team"] = results["Team"].str.replace("Independence/Gil.", "Independence/Gilmanton")
        results["Team"] = results["Team"].str.replace("Stevens Point Area Senior High", "Stevens Point")
        results["Team"][results["Team"].str.contains("Racine St.")] = "Racine St. Catherines"
        # Same thing for teams played
        results["Teams_Played"] = results["Teams_Played"].str.replace("McDonell Central Catholic", "McDonell Catholic")
        results["Teams_Played"] = results["Teams_Played"].str.replace("Independence/Gil.", "Independence/Gilmanton")
        results["Teams_Played"] = results["Teams_Played"].str.replace("Stevens Point Area Senior High", "Stevens Point")
        results["Teams_Played"] = results["Teams_Played"].str.replace("Racine St. Catherine's", "Racine St. Catherines")
        results = results.drop_duplicates(keep="last").reset_index(drop=True)
    # Return results DataFrame
    return results

def get_tournament_seeds(year=None):
    """
    get_tournament_seeds is a method that returns the tournament seeds from the file of tournament seeds from the 
    2022, 2023, and 2024 versions of the WIAA girls state tournament. This file will have:
    - Team (name)
    - Division of the team for that season of the tournament
    - Sectional of the team for that season of the tournament
    - Seed of the team for that season of the tournment
    - Year of tournament for each team
    year: an int, this should be the year that ends each season (e.g. 2024 is for 2023-24 season); only
          allowable values for now are 2022 through 2024. Defaults to None

    returns a pandas DataFrame - tournament seeds
    """
    # Load in the tournament seeds for each year
    tourney = pd.read_excel("/Users/edebroux/Documents/GHS Basketball/gibraltar_basketball/wiaaWebscrape/Tournament Seeds 2022 and 2023 WI GBB.xlsx").iloc[1:, :]
    # If no year is entered
    if year is None:
        return tourney
    else:
        if int(year) == 2022:
            t22 = tourney[tourney.Year == 2022].reset_index(drop=True)
            return t22
        elif int(year) == 2023:
            t23 = tourney[tourney.Year == 2023].reset_index(drop=True)
            return t23
        elif int(year) == 2024:
            t24 = tourney[tourney.Year == 2024].reset_index(drop=True)
            return t24
        else:
            return tourney

def merge_tournament(year=2024):
    """
    merge_tournament is a method that tries to merge the results DataFrame and the tournament seeds DataFrame

    year: an int; the year of the tournament you are analyze

    returns merged DataFrame with the tournament seeds and results, and a list of teams with a tournament seed but missing records
    """
    # Get the results
    results = get_results(year=int(year)-1)
    # Clean backslash and hyphens
    # results["Team"] = results['Team'].str.replace('-', ' ', regex=True)
    # results["Team"] = results['Team'].str.replace('/', ' ', regex=True)
    # # Clean team names in results DataFrame
    # results["Team"] = results['Team'].str.replace('[{}]'.format(string.punctuation), '', regex=True)
    # # Get the tournament seeds
    tourney = get_tournament_seeds(year=year)
    # # Clean backslash and hyphens
    # tourney["Team"] = tourney['Team'].str.replace('-', ' ', regex=True)
    # tourney["Team"] = tourney['Team'].str.replace('/', ' ', regex=True)
    # # Clean team names in results DataFrame
    # tourney["Team"] = tourney["Team"].str.replace('[{}]'.format(string.punctuation), '', regex=True)
    # Merge tournament results
    tr = results.merge(right=tourney, on="Team", how="outer")
    # Handle Racine St. Catherine's case - hoping removing punctuation helps
    # rsc = tr.index[tr["Team"].str.contains("Racine St.")].tolist()
    # # Overwrite the first row with Racine St. Catherine's tournament data if there is more than 1 row with Racine St. Catherine's data
    # if len(rsc) > 1:
    #     tr.iloc[int(rsc[0]), 6:] = seeds_results_23.iloc[int(rsc[1]), 6:]
    # else:
    #     pass
    # Check for any Teams with no game results, but have tournament seeds
    missing_results = tr[(tr["Enrollment"].isnull()==True)]["Team"].tolist()
    # Return the merged DataFrame and the list of teams with missing results
    return tr, missing_results

def clean_teams_played(team_list):
    """
    clean_teams_played takes a list of teams that were played by a team in a season and 
    cleans the list by splitting the team names and removing any unnecessary characters

    team_list: a str; this would be the list of teams a team played in a season

    returns a list of strings that are the teams played by a team in a given season
    """
    # Split the list of teams
    teams_played_all = str(team_list).split("', ")
    # Clean the strings by looping throgh the list
    for i in range(len(teams_played_all)):
        teams_played_all[i] = str(teams_played_all[i]).replace("[", "")
        teams_played_all[i] = str(teams_played_all[i]).replace("]", "")
        teams_played_all[i] = str(teams_played_all[i]).replace("'", "")
        teams_played_all[i] = str(teams_played_all[i]).replace('"', '')
    # Return the cleaned list of teams played
    return teams_played_all

def clean_game_scores(game_list):
    """
    clean_game_scores is a method that cleans a list of scores for a team in a given year

    game_list: a str; this is a string that is written as a list that we use to get the
    list of scores for each game a team plays

    retrns a list of strings that contains the scores
    """
    # Split the list of scores
    game_scores = str(game_list).split("', ")
    # Loop throgh and collect the game scores
    for i in range(len(game_scores)):
        game_scores[i] = str(game_scores[i]).replace("[", "")
        game_scores[i] = str(game_scores[i]).replace("]", "")
        game_scores[i] = str(game_scores[i]).replace("'", "")
    # Return the cleaned list of scores from each game played
    return game_scores

def clean_dates(date_list, year):
    """
    clean_dates is a method that takes the list of strings pulled from the WIAA website
    and converts them to a list of datetime objects

    date_list: a str; this is a list casted to a string that would have all the dates
    that a game was played on
    year: an int; this would be the year of the tournament. Primarily used if a date 
    does not get cast to a datetime object

    returns a list of datetime objects
    """
    # Split the list of dates
    date_of_games = str(date_list).split("', ")
    # Clean dates and convert to datetime object
    for i in range(len(date_of_games)):
        date_of_games[i] = str(date_of_games[i]).replace("[", "")
        date_of_games[i] = str(date_of_games[i]).replace("]", "")
        date_of_games[i] = str(date_of_games[i]).replace("'", "")
        # Try casting to a datetime object
        try:
            date_of_games[i] = datetime.strptime(str(date_of_games[i]), '%m/%d/%Y')
        except ValueError:
            date_of_games[i] = datetime.strptime(f"04/01/{str(year)}", '%m/%d/%Y')
    # Return the list of dates games were played
    return date_of_games

def calculate_records(df, year):
    """
    calculate_records is a method that goes throgh and calculates the record of each team
    during the regular season prior to the seeding date

    df: a pandas DataFrame; the DataFrame will contain all the data pulled for every team
    in the WIAA's website belonging to a recognized conference or WIAA GBB team
    year: an int; the year of the WIAA GBB tournament (e.g. year 2024 would be the tournament
    for the 2023-24 season)

    returns a DataFrame with a boolean of whether a team won, list of points scored by the team in every game,
    list of points scored against every team in every game, a boolean list of games played prior to
    the seeding of the tournament, a boolean list of tournament games
    """
    # Create seeding data DataFrame
    seeding_data = pd.DataFrame({
        "Team": [], # Team name
        "Game_Dates": [], # list of datetime objects with the date of each game
        "Teams_Played": [], # ordered list of strings that contain the names of each teams' opponents
        "Win": [], # list of boolean lists of whether a team won or not
        "Points_For": [], # List of points scored by the team in every game
        "Points_Against": [], # List of points scored against the team in every game
        "Seed_Game": [], # Boolean list that tells us if a game is included in seeding
        "Tourney_Game": [] # Boolean list that tells us if a game is a tournament game
    })
    # Set the data types for each column
    seeding_data["Team"] = seeding_data["Team"].astype(object)
    seeding_data["Game_Dates"] = seeding_data["Game_Dates"].astype(object)
    seeding_data["Teams_Played"] = seeding_data["Teams_Played"].astype(object)
    seeding_data["Win"] = seeding_data["Win"].astype(object)
    seeding_data["Points_For"] = seeding_data["Points_For"].astype(object)
    seeding_data["Points_Against"] = seeding_data["Points_Against"].astype(object)
    seeding_data["Seed_Game"] = seeding_data["Seed_Game"].astype(object)
    seeding_data["Tourney_Game"] = seeding_data["Tourney_Game"].astype(object)
    # Loop throught the DataFrame and start collecting data for each record
    for i in range(len(df)):
        # Set the lists for the seeding DataFrame row i
        win = []
        pts_for = []
        pts_agn = []
        sg = []
        tg = []
        # Collect this data... start by setting the initial team...
        team = str(df.at[ i, "Team"])
        # print off the team's record being calculated - a "verbose" method
        print("Calculating record for: " + str(team))
        # ... and cleaning the list of teams played...
        teams_played = clean_teams_played(df.at[ i, "Teams_Played"])
        # ... and the scores from each game...
        game_scores = clean_game_scores(df.at[ i, "Results"])
        # ... and the dates of each game...
        date_of_games = clean_dates(df.at[ i, "Dates"], year=year)
        # Add entries to row i of seeding data
        # Start by getting the first day of the tournament indicator and
        # seeding game indicator cutoffs
        if year > 2024 or year < 2022:
            print("Not a tournament year for which we have data.")
        elif year == 2022:
            tournament_game = datetime(2022, 2, 22, 0, 0) #Tourney started 2/22/22
            seeding_game = datetime(2022, 2, 13, 0, 0) #Games after 2/13/22 not considered in seeding (mostly :/)
        elif year == 2023:
            tournament_game = datetime(2023, 2, 21, 0, 0) #Tourney started 2/21/23
            seeding_game = datetime(2023, 2, 12, 0, 0) #Games after 2/12/23 not considered in seeding
        else:
            tournament_game = datetime(2024, 2, 20, 0, 0) #Tourney started 2/20/24
            seeding_game = datetime(2024, 2, 11, 0, 0) #Games after 2/11/24 not considered in seeding
        # Now, let's start to load in our data
        for j in range(len(teams_played)):
            # Tournament game indicator
            if tournament_game <= date_of_games[j]:
                tg.append(True)
            else:
                tg.append(False)
            # Seeding game indicator
            if seeding_game <= date_of_games[j]:
                sg.append(False)
            else:
                sg.append(True)
            # # Add seeding game indicators if mismatching lengths
            # if len(sg) < len(tg):
            #     sg.append(False)
            # Append the score from each game to the score for and against array
            try:
                # Split the score
                result = str(game_scores[j])[0]
                s0 = game_scores[j].split("-")[0][2:] # Take value from W xx(x)-
                s1 = game_scores[j].split("-")[1][:3] # Take value from -xx(x or whitespace)
                if result == "W":
                    # Add points for and points against on season
                    pts_for.append(max([float(str(s0).replace(" ", "")), float(str(s1).replace(" ", ""))]))
                    pts_agn.append(min([float(str(s0).replace(" ", "")), float(str(s1).replace(" ", ""))]))
                elif result == "L":
                    # Add points for and points against on season
                    pts_for.append(min([float(str(s0).replace(" ", "")), float(str(s1).replace(" ", ""))]))
                    pts_agn.append(max([float(str(s0).replace(" ", "")), float(str(s1).replace(" ", ""))]))
                else:
                    print("No results")
                    continue
            except ValueError:
                pts_for = []
                pts_agn = []
            except IndexError:
                pts_for = []
                pts_agn = []
            # Win-loss indicator based on appending the points for and against comparison
            try:
                # Split the score
                result = str(game_scores[j])[0]
                if result == "W":
                    win.append(True)
                elif result == "L":
                    win.append(False)
                else:
                    print("No result")
                    continue
            except ValueError:
                win = []
            except IndexError:
                win = []
        # Check to see if seeding game boolean is shorter than the date of games
        if len(sg)+1 == len(date_of_games):
            sg.append(False)
        # Okay, let's start compiling our seeding data:
        seeding_data.at[i, "Team"] = str(team)
        # Set these columns as objects
        seeding_data.at[i, "Win"] = win
        seeding_data.at[i, "Teams_Played"] = teams_played
        seeding_data.at[i, "Game_Dates"] = date_of_games
        seeding_data.at[i, "Points_For"] = pts_for
        seeding_data.at[i, "Points_Against"] = pts_agn
        seeding_data.at[i, "Seed_Game"] = sg
        seeding_data.at[i, "Tourney_Game"] = tg
    # Once we have looped through and calculated all the data, return the DataFrame
    return seeding_data

def get_winning_percentages(df, year, stgco=True):
    """
    get_winning_percentage is a method that calculates a teams' winning percentage
    based on the data we pull from the WIAA website

    df: a pandas DataFrame; this should be the pandas DataFrame generated from
    the calculate_records method 
    stgco: a boolean; stands for seeding for tournament games considered only. If True,
    a record is calculated using only games considered for seeding
    year: an int; relevant if the we are calculating records from games that are not 
    tournament games.

    returns a DataFrame that has every teams' winning percentage
    """
    # Create a winning percentage column
    df["wp%"] = [None] * len(df)
    # Create win and loss columns
    df["Wins"] = [None] * len(df)
    df["Losses"] = [None] * len(df)
    # Check if we are only calculating the record based on games only used for seeding
    if stgco:
        # Loop through and calculate the records for each team
        for i in range(len(df)):
            # Loop through and calculate the records
            # Set counters
            wins = 0
            games_played = 0
            for j in range(len(df.at[i, "Win"])):
                if list(df.at[i, "Seed_Game"])[j] == True:
                    games_played += 1
                    if list(df.at[i, "Win"])[j] == True:
                        wins += 1
                    else:
                        continue
                else:
                    continue
            # Calculate the win percentage
            try:
                df.at[i, "w%"] = round(float(wins)/float(games_played), 6)
                df.at[i, "Wins"] = wins
                df.at[i, "Losses"] = games_played - wins
            except ZeroDivisionError:
                df.at[i, "w%"] = 0.
                df.at[i, "Wins"] = wins
                df.at[i, "Losses"] = games_played - wins
    # Sum the # of wins
    else:
        # Loop through and calculate every teams' winning percentage if we are considering all games played
        # This is trickier due to tournament game scores have different formats
        for i in range(len(df)):
            # Consider case where a game a team plays is not a tournament game
            # Set counters
            wins = 0
            games_played = 0
            # Loop through and calculate the number of wins
            for j in range(len(df.at[i, "Win"])):
                # Add games_played
                games_played += 1
                # # Case where a game is not a tourney game
                # if list(df.at[i, "Tourney_Game"])[j] == False:
                # If win is True
                if list(df.at[i, "Win"])[j] == True:
                    wins += 1
                else:
                    continue
                # If we are handling the case where there is a tournament game
                # I think I fixed this, so I am commenting this section out
                # else:
                #     # Check if there is a tournament game
                #     if (j != (len(df.at[i, "Tourney_Game"])-1)) and (int(year) == 2022):
                #         wins += 1
                #     elif (j == (len(df.at[i, "Tourney_Game"])-1)) and (int(year) == 2022) and (df.at[i, "Team"] not in ["Kettle Moraine", "Notre Dame", "Waupun", "Mineral Point", "Randolph"]):
                #         continue
                #     elif (j == (len(df.at[i, "Tourney_Game"])-1)) and (int(year) == 2022) and (df.at[i, "Team"] in ["Kettle Moraine", "Notre Dame", "Waupun", "Mineral Point", "Randolph"]):
                #         wins += 1
                #     elif (j != (len(df.at[i, "Tourney_Game"])-1)) and (int(year) == 2023):
                #         wins += 1
                #     elif (j == (len(df.at[i, "Tourney_Game"])-1)) and (int(year) == 2023) and (df.at[i, "Team"] not in ["Kettle Moraine", "Notre Dame", "Kewauskum", "Laconia", "McDonell Catholic"]):
                #         continue
                #     elif (j == (len(df.at[i, "Tourney_Game"])-1)) and (int(year) == 2023) and (df.at[i, "Team"] in ["Kettle Moraine", "Notre Dame", "Kewauskum", "Laconia", "McDonell Catholic"]):
                #         wins += 1
                #     elif (j != (len(df.at[i, "Tourney_Game"])-1)) and (int(year) == 2024):
                #         wins += 1
                    # elif (j == (len(df.at[i, "Tourney_Game"])-1)) and (int(year) == 2024) and (df.at[i, "Team"] not in ["Arrowhead", "Pewaukee", "Edgewood", "Laconia", "Albany Monticello"]):
                    #     continue
                    # elif (j == (len(df.at[i, "Tourney_Game"])-1)) and (int(year) == 2024) and (df.at[i, "Team"] in ["Arrowhead", "Pewaukee", "Edgewood", "Laconia", "Albany Monticello"]):
                    #     wins += 1
                    # else:
                    #     print("Either the year is out of range, or something went wrong on the processing side and I missed a condition.")
            # Calculate the win percentage
            try:
                df.at[i, "w%"] = round(float(wins)/float(games_played), 6)
                df.at[i, "Wins"] = wins
                df.at[i, "Losses"] = games_played - wins
            except ZeroDivisionError:
                df.at[i, "w%"] = 0.
                df.at[i, "Wins"] = 0. 
                df.at[i, "Losses"] = 0.
    # Return the DataFrame with the calculated win percentage, number of wins, and number of losses
    return df 

def get_opp_winning_percentages(df, year, stgco=True):
    """
    get_opp_winning_percentages is a method that calculates the number of wins
    and losses each teams' opponents and defeated opponents accumulated over a season.
    
    df: a pandas DataFrame; this is a pandas DataFrame that has passed through
    the get_winning_percentages method prior to running this method. Every teams'
    winning percentage that they play needs to be in the DataFrame.
    stgco: a boolean; stands for seeding for tournament games considered only. If True,
    a record is calculated using only games considered for seeding
    year: an int; this would be the year we are calculating the winning percentage
    metrics for

    returns a pandas DataFrame with every teams' opponents' winning percentages and
    defeated opponents' winning percentages calculated
    """
    # Set counts for opponents wins and losses
    df["Opponent_Wins"] = 0.
    df["Opponent_Losses"] = 0. 
    df["Defeated_Opponent_Wins"] = 0.
    df["Defeated_Opponent_Losses"] = 0. 
    # Loop through and grab the teams played
    for i in range(len(df)):
        # Print which team you are getting the winning percentage for
        print(f"Calculating opponent win perceentage for: {df.at[i, "Team"]}")
        # Verbose method to track team record being calculated
        # print("Calculating opponent record of: " + str(df.at[i, "Team"]))
        # Clean the team names
        teams_played_all = clean_teams_played(df.at[i, "Teams_Played"])
        # Get a unique list of teams - no double counting W-L
        teams_played_set = set()
        # Get date of games
        #date_of_games = clean_dates(df.at[i, "Game_Dates"], year=year)
        # Compare length of these lists
        if len(list(df.at[i, "Seed_Game"])) < len(list(df.at[i, "Game_Dates"])):
            df.at[i, "Seed_Game"] = list(df.at[i, "Seed_Game"]).insert(-1, False)
        elif len(list(df.at[i, "Seed_Game"])) < len(list(df.at[i, "Game_Dates"])):
            df.at[i, "Game_Dates"] = list(df.at[i, "Game_Dates"]).append(datetime.strptime(f"04/01/{str(year)}", '%m/%d/%Y'))
        print("Length of Seed Game Boolean list: " + str(len(df.at[i, "Seed_Game"])))
        print("Length of Date of Games List: " + str(len(df.at[i, "Game_Dates"])))
        # Get the team name
        for j in range(len(df.at[i, "Game_Dates"])):
            # If considering only games used to seed the tournament
            if stgco and list(df.at[i, "Seed_Game"])[j] == True:
                # Check if the opponent is not in the set of unique teams
                if teams_played_all[j] not in teams_played_set:
                    try:
                        df.at[i, "Opponent_Wins"] += float(df[df["Team"] == str(teams_played_all[j])]["Wins"].values[0])
                        df.at[i, "Opponent_Losses"] += float(df[df["Team"] == str(teams_played_all[j])]["Losses"].values[0])
                        # Check if the team won or lost to calculate defeated opponent W-L record
                        if list(df.at[i, "Win"])[j] == True:
                            df.at[i, "Defeated_Opponent_Wins"] += float(df[df["Team"] == str(teams_played_all[j])]["Wins"].values[0])
                            df.at[i, "Defeated_Opponent_Losses"] += float(df[df["Team"] == str(teams_played_all[j])]["Losses"].values[0])
                        else:
                            continue
                    # out of state/non-WIAA affiliated case
                    except IndexError:
                        df.at[i, "Opponent_Wins"] += 10.
                        df.at[i, "Opponent_Losses"] += 10.
                        # Handle case where the team won - commenting out since I don't think this is included
                        if list(df.at[i, "Win"])[j] == True:
                            df.at[i, "Defeated_Opponent_Wins"] += 10.
                            df.at[i, "Defeated_Opponent_Losses"] += 10.
                        else:
                            continue
                        #Add team to list of teams played
                        teams_played_set.add(teams_played_all[j])
                else:
                        continue
                # Out of state consideration
                
            # Case where we are only considering seeding games, but the game did
            # not count towards seeding
            elif stgco and list(df.at[i, "Seed_Game"])[j] == False:
                continue
            # If calculating opponent Win % based on all games played
            else:
                if teams_played_all not in teams_played_set:
                # Check if the opponent is not in the set of unique teams
                    try:
                        df.at[i, "Opponent_Wins"] += float(df[df["Team"] == str(teams_played_all[j])]["Wins"].values[0])
                        df.at[i, "Opponent_Losses"] += float(df[df["Team"] == str(teams_played_all[j])]["Losses"].values[0])
                        # Calculation when if the team won against Team j
                        if list(df.at[i, "Win"])[j] == True:
                                df.at[i, "Defeated_Opponent_Wins"] += float(df[df["Team"] == str(teams_played_all[j])]["Wins"].values[0])
                                df.at[i, "Defeated_Opponent_Losses"] += float(df[df["Team"] == str(teams_played_all[j])]["Losses"].values[0])
                        else:
                            continue
                        # Add team to a list of teams played
                        teams_played_set.add(teams_played_all[j])
                    # Out of state case
                    except IndexError:
                        df.at[i, "Opponent_Wins"] += 10.
                        df.at[i, "Opponent_Losses"] += 10.
                        #  Handle case where the team won - commenting out because I don't think this is included
                        if list(df.at[i, "Win"])[j] == True:
                            df.at[i, "Defeated_Opponent_Wins"] += 10.
                            df.at[i, "Defeated_Opponent_Losses"] += 10.
                        else:
                            continue
                else:
                    continue
    # Calculate the Opponent Win % and Defeated Opponent Win %
    try:
        df["ow%"] = round((df["Opponent_Wins"]) / (df["Opponent_Wins"] + df["Opponent_Losses"]), 6)
        df["dow%"] = round((df["Defeated_Opponent_Wins"]) / (df["Defeated_Opponent_Wins"] + df["Defeated_Opponent_Losses"]), 6)
    except ZeroDivisionError:
        df["ow%"] = 0. 
        df["dow%"] = 0.
    # Return the DataFrame with the calculated opponent win %
    return df

def get_opp_opp_winning_percentages(df, year, stgco=True, noos=False):
    """
    get_opp_opp_winning_percentages is a method that calculates the number of wins
    and losses from each teams' list of opponents' opponents and the defeated opponents'
    opponents' winning percentages
    
    df: a pandas DataFrame; this is a pandas DataFrame that has passed through
    the get_opp_winning_percentages method prior to running this method. Every teams'
    winning percentage that they play needs to be in the DataFrame.
    year: an int; this would be the year we are calculating the winning percentage
    metrics for
    stgco: a boolean; stands for seeding for tournament games considered only. If True,
    a record is calculated using only games considered for seeding
    noos; a boolean; stands for no out-of-state. Means that any game played against an
    out-of-state team is not added to the opponents' opponents' win and loss total.
    Defaults to False since I am pretty sure the WIAA does not use these opponents' 
    records in their tabulations. If true, we imagine they play 20 games and their opponents
    play 20 games, so their opponents win half their games

    returns a pandas DataFrame with every teams' opponents' opponents winning percentages
    and defeated opponents' opponents winning percentages calculated
    """
    # Set counts for opponents wins and losses
    df["Opponent_Opponent_Wins"] = 0.
    df["Opponent_Opponent_Losses"] = 0. 
    df["Defeated_Opponent_Opponent_Wins"] = 0. 
    df["Defeated_Opponent_Opponent_Losses"] = 0.
    # Loop through and calculate Opponents' Opponents' Wins and Losses
    for i in range(len(df)):
        # Print team name you are calculating
        print(f"Calculating opponents' opponents' win percentage for team: {df.at[i, "Team"]}")
        # Clean the team names
        teams_played_all = clean_teams_played(df.at[i, "Teams_Played"])
        # Get a unique list of teams - no double counting W-L
        teams_played_set = set()
        # Get the opponent name and calculate the wins and losses
        for j in range(len(df.at[i, "Game_Dates"])):
            # If considering only games used to seed the tournament
            if stgco:
                # Check if the game is a seed game
                if list(df.at[i, "Seed_Game"])[j] == True:
                    # Check if the opponent is not in the set of unique teams
                    if teams_played_all[j] not in teams_played_set:
                        try:
                            df.at[i, "Opponent_Opponent_Wins"] += float(df[df["Team"] == str(teams_played_all[j])]["Opponent_Wins"].values[0])
                            df.at[i, "Opponent_Opponent_Losses"] += float(df[df["Team"] == str(teams_played_all[j])]["Opponent_Losses"].values[0])
                            # Calculation when if the team won against Team j
                            if list(df.at[i, "Win"])[j] == True:
                                    df.at[i, "Defeated_Opponent_Opponent_Wins"] += float(df[df["Team"] == str(teams_played_all[j])]["Opponent_Wins"].values[0])
                                    df.at[i, "Defeated_Opponent_Opponent_Losses"] += float(df[df["Team"] == str(teams_played_all[j])]["Opponent_Losses"].values[0])
                            else:
                                continue
                            # Add team to a list of teams played
                            teams_played_set.add(teams_played_all[j])
                        except IndexError:
                            if noos:
                                df.at[i, "Opponent_Opponent_Wins"] += 100.
                                df.at[i, "Opponent_Opponent_Losses"] += 100.
                            else:
                                continue
                    else:
                        continue
            # Case if seed game is not True
            else:
                if teams_played_all not in teams_played_set:
                    try:
                        # Check if the opponent is not in the set of unique teams
                        df.at[i, "Opponent_Opponent_Wins"] += float(df[df["Team"] == str(teams_played_all[j])]["Opponent_Wins"].values[0])
                        df.at[i, "Opponent_Opponent_Losses"] += float(df[df["Team"] == str(teams_played_all[j])]["Opponent_Losses"].values[0])
                        # Calculation when if the team won against Team j
                        if list(df.at[i, "Win"])[j] == True:
                                df.at[i, "Defeated_Opponent_Opponent_Wins"] += float(df[df["Team"] == str(teams_played_all[j])]["Opponent_Wins"].values[0])
                                df.at[i, "Defeated_Opponent_Opponent_Losses"] += float(df[df["Team"] == str(teams_played_all[j])]["Opponent_Losses"].values[0])
                        else:
                            continue
                        teams_played_set.add(teams_played_all[j])
                    except IndexError:
                        # If considering out-of-state games in this calculation
                        if noos:
                            df.at[i, "Opponent_Wins"] += 100.
                            df.at[i, "Opponent_Losses"] += 100.
                        else:
                            continue
                else:
                    continue
    # Calculate the opponents' opponents' winning percentage and defeated opponents' opponents' winning percentage
    try:
        df["oow%"] = round((df["Opponent_Opponent_Wins"]) / (df["Opponent_Opponent_Wins"] + df["Opponent_Opponent_Losses"]), 6)
        df["doow%"] = round((df["Defeated_Opponent_Opponent_Wins"]) / (df["Defeated_Opponent_Opponent_Wins"] + df["Defeated_Opponent_Opponent_Losses"]), 6)
    except ZeroDivisionError:
        df["oow%"] = 0.
        df["doow%"] = 0. 
    # Return the DataFrame with the calculated opponent opponent win % and defeated opponent opponent win %
    return df

def return_winning_percentage_dfs(df, year):
    """
    return_winnning_percentage_dfs is a method that returns the:
    - Team Name
    - Seed
    - Division
    - Sectional
    - Seed
    - Year
    - winning percentages

    df: a pandas DataFrame; this should be a pandas DataFrame with all the calculated winning
    percentage data
    year: an int; should be between 2022 and 2024 and is the year of the tournament data was
    created with

    returns a subset with the winning percentages
    """
    # Grab tourney data
    tournament = get_tournament_seeds(year=year)
    # Merge tournament data
    percentages = df.merge(right=tournament, on="Team", how="outer")
    # Returns a DataFrame with the columns listed
    return percentages[["Team", "Division", "Sectional", "Seed", "Year", "w%", "ow%", "oow%", "dow%", "doow%"]]

def return_records_df(df, year):
    """
    return_winnning_percentage_dfs is a method that returns the:
    - Team Name
    - Seed
    - Division
    - Sectional
    - Seed
    - Year
    - Records for each metric

    df: a pandas DataFrame; this should be a pandas DataFrame with all the calculated winning
    percentage data
    year: an int; should be between 2022 and 2024 and is the year of the tournament data was
    created with

    returns a subset with the records:
    - Every teams' Win-Loss record
    - Every teams' Opponents' Win-Loss record
    - Every teams' Opponents' Opponents' Win-Loss record
    - Every teams' Defeated Opponents' Win-Loss record
    - Every teams' Defeated Opponents' Opponents' Win-Loss record
    """
    # Grab tourney data
    tournament = get_tournament_seeds(year=year)
    # Merge the tournament data and records data
    records = df.merge(right=tournament, on="Team", how="outer")
    # Returns a DataFrame with the columns listed
    return records[[
        "Team", 
        "Division", 
        "Sectional", 
        "Seed", 
        "Year",
        "Wins",
        "Losses",
        "Opponent_Wins",
        "Opponent_Losses",
        "Opponent_Opponent_Wins",
        "Opponent_Opponent_Losses",
        "Defeated_Opponent_Wins",
        "Defeated_Opponent_Losses",
        "Defeated_Opponent_Opponent_Wins",
        "Defeated_Opponent_Opponent_Losses"
    ]]

def return_elo_input_data(df, year):
    """
    return_elo_input_data is a method that outputs a subset of the calculated
    data used to calculate an adjusted ELO Rating system

    df: a pandas DataFrame; this should be the pandas DataFrame that contains
        all of our seeding data
    year: an int; should be between 2022 and 2024 and is the year of the tournament data was
    created with

    returns a DataFrame with:
    - Team
    - Division
    - Date of Games
    - Sectional
    - Seed
    - Year
    - Win Boolean
    - Points Scored
    - Points Against
    - Opponents
    """
    # Grab tourney data
    tournament = get_tournament_seeds(year=year)
    # Merge the tournament data and ELO-based data
    elo_input = df.merge(right=tournament, on="Team", how="outer")
    # Return the data used to calculate the ELO ratings
    return elo_input[[
        "Team", 
        "Division", 
        "Sectional", 
        "Seed", 
        "Year", 
        "Game_Dates",
        "Win", 
        "Points_For", 
        "Points_Against"
     ]]

# %% [markdown]
# Alright with all of our methods written out, let's see if our code works.

# %%
# Merge tournament seeds and results for 2023 tourney
tr_2223, missing_23 = merge_tournament(year=2023)
# Merge results and seeds for 2024 tourney
tr_2324, missing_24 = merge_tournament(year=2024)
# View DataFrame for 2023-24 season
tr_2324.head()
# Out:
#                                   Team  Enrollment  \
# 0                           Abbotsford       244.0
# 1  Abundant Life Christian/St. Ambrose       211.0
# 2                     Adams-Friendship       432.0
# 3                    Albany/Monticello       178.0
# 4                               Algoma       219.0
#
#                                              Website  \
# 0  https://schools.wiaawi.org/Directory/Schedule/...
# 1  https://schools.wiaawi.org/Directory/Schedule/...
# 2  https://schools.wiaawi.org/Directory/Schedule/...
# 3  https://schools.wiaawi.org/Directory/Schedule/...
# 4  https://schools.wiaawi.org/Directory/Schedule/...
#
#                                         Teams_Played  \
# 0  ['Athens', 'Colby', 'Prentice', 'Greenwood', '...
# 1  ['Juda', 'Central WI Christian', 'Parkview', '...
# 2  ['Cambridge', 'Poynette', 'Marshall', 'Amherst...
# 3  ['Benton', 'Turner', 'Belleville', 'Williams B...
# 4  ['Bonduel', 'Freedom', 'Mishicot', 'Green Bay ...
#
#                                              Results  \
# 0  ['L 42-64', 'W 69-29', 'L 36-43', 'L 47-48', '...
# 1  ['W 63-25', 'W 45-28', 'W 52-26', 'L 39-73', '...
# 2  ['L 34-65', 'L 50-53', 'L 36-45', 'L 30-38', '...
# 3  ['W 73-26', 'W 47-29', 'W 55-37', 'W 72-18', '...
# 4  ['L 22-45', 'L 27-48', 'L 40-48', 'W 64-36', '...
#
#                                                Dates  Division Sectional  \
# 0  ['11/16/2023', '11/20/2023', '11/21/2023', '11...       4.0        1B
# 1  ['11/14/2023', '11/16/2023', '11/20/2023', '11...       4.0        4B
# 2  ['11/14/2023', '11/16/2023', '11/20/2023', '11...       3.0        1B
# 3  ['11/14/2023', '11/16/2023', '11/18/2023', '11...       5.0        4B
# 4  ['11/14/2023', '11/16/2023', '11/27/2023', '11...       4.0        2B
#
#    Seed    Year
# 0   5.0  2024.0
# 1   5.0  2024.0
# 2   9.0  2024.0
# 3   1.0  2024.0
# 4   6.0  2024.0

# %%
print(len((str(tr_2324[tr_2324["Team"] =="Bloomer"]["Results"].to_list()).split(","))))
# Out:
# 26

# %%
# View teams with missing records
missing_24
# Out:
# ['St. Marys Springs']

# %%
missing_23
# Out:
# ['St. Croix Falls', 'St. Marys Springs', 'Stevens Point', 'Wisconsin Rapids']

# %%
tr_2324[tr_2324.Team.str.contains("Mary")]
# Out:
#                     Team  Enrollment  \
# 365  Saint Mary Catholic       277.0
# 398   St. Mary's Springs       263.0
# 399    St. Marys Springs         NaN
#
#                                                Website  \
# 365  https://schools.wiaawi.org/Directory/Schedule/...
# 398  https://schools.wiaawi.org/Directory/Schedule/...
# 399                                                NaN
#
#                                           Teams_Played  \
# 365  ['Bonduel', 'Winneconne', 'Lourdes Acad.', 'Ma...
# 398  ['Howards Grove', 'New Holstein', 'North Fond ...
# 399                                                NaN
#
#                                                Results  \
# 365  ['W 62-53', 'W 63-40', 'W 77-41', 'W 73-48', '...
# 398  ['W 53-49', 'W 57-43', 'W 73-57', 'L 53-58', '...
# 399                                                NaN
#
#                                                  Dates  Division Sectional  \
# 365  ['11/16/2023', '11/21/2023', '11/27/2023', '12...       4.0        2A
# 398  ['11/14/2023', '11/21/2023', '11/28/2023', '12...       NaN       NaN
# 399                                                NaN       4.0        4A
#
#      Seed    Year
# 365   1.0  2024.0
# 398   NaN     NaN
# 399   5.0  2024.0

# %%
tr_2324.iloc[398, 6:] = tr_2324.iloc[399, 6:]
tr_2324 = tr_2324.drop(index=399, axis=0).reset_index(drop=True)
tr_2324.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481 entries, 0 to 480
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Team          481 non-null    object
#  1   Enrollment    481 non-null    float64
#  2   Website       481 non-null    object
#  3   Teams_Played  481 non-null    object
#  4   Results       481 non-null    object
#  5   Dates         481 non-null    object
#  6   Division      458 non-null    float64
#  7   Sectional     458 non-null    object
#  8   Seed          458 non-null    float64
#  9   Year          458 non-null    float64
# dtypes: float64(4), object(6)
# memory usage: 37.7+ KB

# %%
# Calculate the records
seed24 = calculate_records(tr_2324, year=2024)
# Out:
# Calculating record for: Abbotsford
# Calculating record for: Abundant Life Christian/St. Ambrose
# Calculating record for: Adams-Friendship
# Calculating record for: Albany/Monticello
# Calculating record for: Algoma
# Calculating record for: Alma Center Lincoln
# Calculating record for: Alma/Pepin
# Calculating record for: Almond-Bancroft
# Calculating record for: Altoona
# Calculating record for: Amery
# Calculating record for: Amherst
# Calculating record for: Antigo
# Calculating record for: Appleton East
# Calculating record for: Appleton North
# Calculating record for: Appleton West
# Calculating record for: Aquinas
# Calculating record for: Arcadia
# Calculating record for: Argyle/Pecatonica
# Calculating record for: Arrowhead
# Calculating record for: Ashland
# Calculating record for: Ashwaubenon
# Calculating record for: Assumption
# Calculating record for: Athens
# Calculating record for: Auburndale
# Calculating record for: Augusta
# Calculating record for: Badger
# Calculating record for: Baldwin-Woodville
# Calculating record for: Bangor
# Calculating record for: Baraboo
# Calculating record for: Barneveld
# Calculating record for: Barron
# Calculating record for: Bay Port
# Calculating record for: Bayfield
# Calculating record for: Beaver Dam
# Calculating record for: Belleville
# Calculating record for: Belmont
# Calculating record for: Beloit Memorial
# Calculating record for: Benton
# Calculating record for: Berlin
# Calculating record for: Big Foot
# Calculating record for: Birchwood
# Calculating record for: Black Hawk
# Calculating record for: Black River Falls
# Calculating record for: Blair-Taylor
# Calculating record for: Bloomer
# Calculating record for: Bonduel
# Calculating record for: Boscobel
# Calculating record for: Bowler
# Calculating record for: Boyceville
# Calculating record for: Brillion
# Calculating record for: Brodhead
# Calculating record for: Brookfield Academy
# Calculating record for: Brookfield Central
# Calculating record for: Brookfield East
# Calculating record for: Brookwood
# Calculating record for: Brown Deer
# Calculating record for: Bruce
# Calculating record for: Burlington
# Calculating record for: Butternut
# Calculating record for: Cadott
# Calculating record for: Cambria-Friesland
# Calculating record for: Cambridge
# Calculating record for: Cameron
# Calculating record for: Campbellsport
# Calculating record for: Carmen Northwest
# Calculating record for: Cashton
# Calculating record for: Catholic Central
# Calculating record for: Catholic Memorial
# Calculating record for: Cedar Grove-Belgium
# Calculating record for: Cedarburg
# Calculating record for: Central WI Christian
# Calculating record for: Chequamegon
# Calculating record for: Chesterton Academy
# Calculating record for: Chetek-Weyerhaeuser
# Calculating record for: Chilton
# Calculating record for: Chippewa Falls
# Calculating record for: Clayton
# Calculating record for: Clear Lake
# Calculating record for: Clinton
# Calculating record for: Clintonville
# Calculating record for: Cochrane-Fountain City
# Calculating record for: Colby
# Calculating record for: Coleman
# Calculating record for: Colfax
# Calculating record for: Columbus
# Calculating record for: Columbus Catholic
# Calculating record for: Cornell
# Calculating record for: Crandon
# Calculating record for: Cristo Rey Jesuit
# Calculating record for: Crivitz
# Calculating record for: Cuba City
# Calculating record for: Cudahy
# Calculating record for: Cumberland
# Calculating record for: D.C. Everest
# Calculating record for: Darlington
# Calculating record for: De Pere
# Calculating record for: De Soto
# Calculating record for: DeForest
# Calculating record for: Deerfield
# Calculating record for: Delavan-Darien
# Calculating record for: Denmark
# Calculating record for: Destiny
# Calculating record for: Divine Savior Holy Angels
# Calculating record for: Dodgeland
# Calculating record for: Dodgeville
# Calculating record for: Dominican
# Calculating record for: Drummond
# Calculating record for: Durand-Arkansaw
# Calculating record for: East Troy
# Calculating record for: Eastbrook Academy
# Calculating record for: Eau Claire Immanuel Lutheran
# Calculating record for: Eau Claire Memorial
# Calculating record for: Eau Claire North
# Calculating record for: Edgar
# Calculating record for: Edgerton
# Calculating record for: Edgewood
# Calculating record for: Elcho
# Calculating record for: Eleva-Strum
# Calculating record for: Elk Mound
# Calculating record for: Elkhart Lake-Glenbeulah
# Calculating record for: Elkhorn
# Calculating record for: Ellsworth
# Calculating record for: Evansville
# Calculating record for: Faith Christian (Wms Bay)
# Calculating record for: Fall Creek
# Calculating record for: Fall River
# Calculating record for: Fennimore
# Calculating record for: Flambeau
# Calculating record for: Florence
# Calculating record for: Fond du Lac
# Calculating record for: Fort Atkinson
# Calculating record for: Fox Valley Lutheran
# Calculating record for: Franklin
# Calculating record for: Frederic
# Calculating record for: Freedom
# Calculating record for: Gale-Ettrick-Trempealeau
# Calculating record for: Germantown
# Calculating record for: Gibraltar
# Calculating record for: Gillett
# Calculating record for: Gilman
# Calculating record for: Gilmanton
# Calculating record for: Glenwood City
# Calculating record for: Golda Meir
# Calculating record for: Goodman/Pembine
# Calculating record for: Grafton
# Calculating record for: Granton
# Calculating record for: Grantsburg
# Calculating record for: Green Bay East
# Calculating record for: Green Bay N.E.W. Lutheran/Providence Academy (Green Bay)
# Calculating record for: Green Bay Preble
# Calculating record for: Green Bay Southwest
# Calculating record for: Green Bay West
# Calculating record for: Greendale
# Calculating record for: Greenfield
# Calculating record for: Greenwood
# Calculating record for: Gresham
# Calculating record for: Hamilton
# Calculating record for: Hartford
# Calculating record for: Hayward
# Calculating record for: Heritage Christian
# Calculating record for: Highland
# Calculating record for: Hilbert
# Calculating record for: Hillsboro
# Calculating record for: Hmong American Peace
# Calculating record for: Holmen
# Calculating record for: Homestead
# Calculating record for: Horicon
# Calculating record for: Hortonville
# Calculating record for: Howards Grove
# Calculating record for: Hudson
# Calculating record for: Hurley
# Calculating record for: Hustisford
# Calculating record for: Independence/Gilmanton
# Calculating record for: Iola-Scandinavia
# Calculating record for: Iowa-Grant
# Calculating record for: Ithaca
# Calculating record for: Janesville Craig
# Calculating record for: Janesville Parker
# Calculating record for: Jefferson
# Calculating record for: Johnson Creek
# Calculating record for: Juda
# Calculating record for: Kaukauna
# Calculating record for: Kenosha Bradford
# Calculating record for: Kenosha Christian Life
# Calculating record for: Kenosha Indian Trail
# Calculating record for: Kenosha St. Joseph Catholic
# Calculating record for: Kenosha Tremper
# Calculating record for: Kettle Moraine
# Calculating record for: Kettle Moraine Lutheran
# Calculating record for: Kewaskum
# Calculating record for: Kewaunee
# Calculating record for: Kickapoo
# Calculating record for: Kiel
# Calculating record for: Kimberly
# Calculating record for: Kohler
# Calculating record for: La Crosse Central
# Calculating record for: La Crosse Logan
# Calculating record for: La Farge/Youth Initiative
# Calculating record for: Lac Courte Oreilles
# Calculating record for: Laconia
# Calculating record for: Ladysmith
# Calculating record for: Lake Country Lutheran
# Calculating record for: Lake Holcombe
# Calculating record for: Lake Mills
# Calculating record for: Lakeland
# Calculating record for: Lakeside Lutheran
# Calculating record for: Lancaster
# Calculating record for: Lena
# Calculating record for: Little Chute
# Calculating record for: Living Word Lutheran
# Calculating record for: Lodi
# Calculating record for: Lomira
# Calculating record for: Lourdes Acad.
# Calculating record for: Loyal
# Calculating record for: Luck
# Calculating record for: Luther
# Calculating record for: Luxemburg-Casco
# Calculating record for: Madison Country Day
# Calculating record for: Madison East
# Calculating record for: Madison La Follette
# Calculating record for: Madison Memorial
# Calculating record for: Madison West
# Calculating record for: Manawa
# Calculating record for: Manitowoc Lincoln
# Calculating record for: Manitowoc Lutheran
# Calculating record for: Marathon
# Calculating record for: Marinette
# Calculating record for: Marion
# Calculating record for: Markesan
# Calculating record for: Marshall
# Calculating record for: Marshfield
# Calculating record for: Martin Luther
# Calculating record for: Mauston
# Calculating record for: Mayville
# Calculating record for: McDonell Catholic
# Calculating record for: McFarland
# Calculating record for: Medford
# Calculating record for: Mellen
# Calculating record for: Melrose-Mindoro
# Calculating record for: Menasha
# Calculating record for: Menominee Indian
# Calculating record for: Menomonee Falls
# Calculating record for: Menomonie
# Calculating record for: Mercer
# Calculating record for: Merrill
# Calculating record for: Messmer
# Calculating record for: Middleton
# Calculating record for: Milton
# Calculating record for: Milwaukee Academy of Science
# Calculating record for: Milwaukee Bay View
# Calculating record for: Milwaukee Bradley Tech/Milwaukee Arts
# Calculating record for: Milwaukee Hamilton/Audubon
# Calculating record for: Milwaukee Juneau
# Calculating record for: Milwaukee King
# Calculating record for: Milwaukee Lutheran
# Calculating record for: Milwaukee Madison
# Calculating record for: Milwaukee Marshall
# Calculating record for: Milwaukee North
# Calculating record for: Milwaukee Pulaski/Carmen South/Carmen Southeast
# Calculating record for: Milwaukee Reagan
# Calculating record for: Milwaukee Riverside
# Calculating record for: Milwaukee School of Languages
# Calculating record for: Milwaukee South
# Calculating record for: Milwaukee Vincent
# Calculating record for: Milwaukee Washington/Fuller Collegiate
# Calculating record for: Mineral Point
# Calculating record for: Mishicot
# Calculating record for: Mondovi
# Calculating record for: Monona Grove
# Calculating record for: Monroe
# Calculating record for: Montello
# Calculating record for: Mosinee
# Calculating record for: Mount Horeb
# Calculating record for: Mukwonago
# Calculating record for: Muskego
# Calculating record for: Necedah
# Calculating record for: Neenah
# Calculating record for: Neillsville
# Calculating record for: Nekoosa
# Calculating record for: New Auburn
# Calculating record for: New Berlin Eisenhower
# Calculating record for: New Berlin West
# Calculating record for: New Glarus
# Calculating record for: New Holstein
# Calculating record for: New Lisbon
# Calculating record for: New London
# Calculating record for: New Richmond
# Calculating record for: Newman Catholic
# Calculating record for: Niagara
# Calculating record for: Nicolet
# Calculating record for: North Crawford
# Calculating record for: North Fond du Lac
# Calculating record for: Northland Lutheran
# Calculating record for: Northland Pines
# Calculating record for: Northwestern
# Calculating record for: Northwood
# Calculating record for: Notre Dame
# Calculating record for: Oak Creek
# Calculating record for: Oakfield
# Calculating record for: Obama SCTE
# Calculating record for: Oconomowoc
# Calculating record for: Oconto
# Calculating record for: Oconto Falls
# Calculating record for: Omro
# Calculating record for: Onalaska
# Calculating record for: Oneida Nation
# Calculating record for: Oostburg
# Calculating record for: Oregon
# Calculating record for: Osceola
# Calculating record for: Oshkosh North
# Calculating record for: Oshkosh West
# Calculating record for: Osseo-Fairchild
# Calculating record for: Owen-Withee
# Calculating record for: Ozaukee
# Calculating record for: Pacelli
# Calculating record for: Palmyra-Eagle
# Calculating record for: Pardeeville
# Calculating record for: Parkview
# Calculating record for: Peshtigo
# Calculating record for: Pewaukee
# Calculating record for: Phelps
# Calculating record for: Phillips
# Calculating record for: Pittsville
# Calculating record for: Pius XI Catholic
# Calculating record for: Platteville
# Calculating record for: Plum City/Elmwood
# Calculating record for: Plymouth
# Calculating record for: Port Edwards
# Calculating record for: Port Washington
# Calculating record for: Portage
# Calculating record for: Potosi/Cassville
# Calculating record for: Poynette
# Calculating record for: Prairie Farm
# Calculating record for: Prairie du Chien
# Calculating record for: Prentice
# Calculating record for: Prescott
# Calculating record for: Princeton/Green Lake
# Calculating record for: Pulaski
# Calculating record for: Racine Case
# Calculating record for: Racine Horlick
# Calculating record for: Racine Lutheran
# Calculating record for: Racine Park
# Calculating record for: Racine St. Catherines
# Calculating record for: Randolph
# Calculating record for: Random Lake
# Calculating record for: Reedsburg
# Calculating record for: Reedsville
# Calculating record for: Regis
# Calculating record for: Rhinelander
# Calculating record for: Rib Lake
# Calculating record for: Rice Lake
# Calculating record for: Richland Center
# Calculating record for: Rio
# Calculating record for: Ripon
# Calculating record for: River Falls
# Calculating record for: River Ridge
# Calculating record for: River Valley
# Calculating record for: Riverdale
# Calculating record for: Roncalli
# Calculating record for: Rosholt
# Calculating record for: Royall
# Calculating record for: Saint Anthony
# Calculating record for: Saint Croix Falls
# Calculating record for: Saint Francis
# Calculating record for: Saint Joan Antida/Tenor/Veritas
# Calculating record for: Saint Mary Catholic
# Calculating record for: Saint Thomas Aquinas
# Calculating record for: Saint Thomas More
# Calculating record for: Salam
# Calculating record for: Sauk Prairie
# Calculating record for: Seneca
# Calculating record for: Sevastopol
# Calculating record for: Seymour
# Calculating record for: Shawano
# Calculating record for: Sheboygan Christian
# Calculating record for: Sheboygan Falls
# Calculating record for: Sheboygan Lutheran
# Calculating record for: Sheboygan North
# Calculating record for: Sheboygan South
# Calculating record for: Shell Lake
# Calculating record for: Shiocton
# Calculating record for: Shoreland Lutheran
# Calculating record for: Shorewood
# Calculating record for: Shullsburg
# Calculating record for: Siren
# Calculating record for: Slinger
# Calculating record for: Solon Springs
# Calculating record for: Somerset
# Calculating record for: South Milwaukee
# Calculating record for: South Shore
# Calculating record for: Southern Door
# Calculating record for: Southwestern
# Calculating record for: Sparta
# Calculating record for: Spencer
# Calculating record for: Spooner
# Calculating record for: Spring Valley
# Calculating record for: St. Augustine Prep
# Calculating record for: St. Croix Central
# Calculating record for: St. Mary's Springs
# Calculating record for: Stanley-Boyd
# Calculating record for: Stevens Point
# Calculating record for: Stockbridge
# Calculating record for: Stoughton
# Calculating record for: Stratford
# Calculating record for: Sturgeon Bay
# Calculating record for: Sun Prairie East
# Calculating record for: Sun Prairie West
# Calculating record for: Superior
# Calculating record for: Suring
# Calculating record for: The Prairie School
# Calculating record for: Thorp
# Calculating record for: Three Lakes/Phelps
# Calculating record for: Tigerton
# Calculating record for: Tomah
# Calculating record for: Tomahawk
# Calculating record for: Tri-County
# Calculating record for: Turner
# Calculating record for: Turtle Lake
# Calculating record for: Two Rivers
# Calculating record for: Union Grove
# Calculating record for: Unity
# Calculating record for: University Lake School Co-op
# Calculating record for: University School of Milwaukee
# Calculating record for: Valders
# Calculating record for: Valley Christian (Oshkosh)
# Calculating record for: Valley Christian School (Osceola)
# Calculating record for: Verona
# Calculating record for: Viroqua
# Calculating record for: Wabeno/Laona
# Calculating record for: Washburn
# Calculating record for: Washington Island
# Calculating record for: Waterford
# Calculating record for: Waterloo
# Calculating record for: Watertown
# Calculating record for: Watertown Luther Prep
# Calculating record for: Waukesha North/Waukesha South
# Calculating record for: Waukesha South
# Calculating record for: Waukesha West
# Calculating record for: Waunakee
# Calculating record for: Waupaca
# Calculating record for: Waupun
# Calculating record for: Wausau East
# Calculating record for: Wausau West
# Calculating record for: Wausaukee
# Calculating record for: Wautoma
# Calculating record for: Wauwatosa East
# Calculating record for: Wauwatosa West
# Calculating record for: Wauzeka-Steuben
# Calculating record for: Wayland Academy
# Calculating record for: Webster
# Calculating record for: West Allis Central
# Calculating record for: West Allis Hale
# Calculating record for: West Bend East
# Calculating record for: West Bend West
# Calculating record for: West De Pere
# Calculating record for: West Salem
# Calculating record for: Westby
# Calculating record for: Westfield
# Calculating record for: Weston
# Calculating record for: Westosha Central
# Calculating record for: Weyauwega-Fremont
# Calculating record for: White Lake
# Calculating record for: Whitefish Bay
# Calculating record for: Whitehall
# Calculating record for: Whitewater
# Calculating record for: Whitnall
# Calculating record for: Wild Rose
# Calculating record for: Williams Bay
# Calculating record for: Wilmot
# Calculating record for: Winnebago Lutheran
# Calculating record for: Winneconne
# Calculating record for: Winter
# Calculating record for: Wisconsin Dells
# Calculating record for: Wisconsin Heights
# Calculating record for: Wisconsin Lutheran
# Calculating record for: Wisconsin Rapids Lincoln
# Calculating record for: Wittenberg-Birnamwood
# Calculating record for: Wonewoc-Center
# Calculating record for: Wrightstown
# Calculating record for: Xavier
# Calculating record for: Young Coggs

# %%
# Calculate the winning % with seeding games considered only
wp24_sgo = get_winning_percentages(df=seed24, year=2024, stgco=True)
wp24_sgo.head()
# Out:
#                                   Team  \
# 0                           Abbotsford
# 1  Abundant Life Christian/St. Ambrose
# 2                     Adams-Friendship
# 3                    Albany/Monticello
# 4                               Algoma
#
#                                           Game_Dates  \
# 0  [2023-11-16 00:00:00, 2023-11-20 00:00:00, 202...
# 1  [2023-11-14 00:00:00, 2023-11-16 00:00:00, 202...
# 2  [2023-11-14 00:00:00, 2023-11-16 00:00:00, 202...
# 3  [2023-11-14 00:00:00, 2023-11-16 00:00:00, 202...
# 4  [2023-11-14 00:00:00, 2023-11-16 00:00:00, 202...
#
#                                         Teams_Played  \
# 0  [Athens, Colby, Prentice, Greenwood, Auburndal...
# 1  [Juda, Central WI Christian, Parkview, Argyle/...
# 2  [Cambridge, Poynette, Marshall, Amherst, Tomah...
# 3  [Benton, Turner, Belleville, Williams Bay, Bel...
# 4  [Bonduel, Freedom, Mishicot, Green Bay N.E.W. ...
#
#                                                  Win  \
# 0  [False, True, False, False, False, True, True,...
# 1  [True, True, True, False, True, True, False, T...
# 2  [False, False, False, False, False, False, Tru...
# 3  [True, True, True, True, True, True, True, Tru...
# 4  [False, False, False, True, False, True, False...
#
#                                           Points_For  \
# 0  [42.0, 69.0, 36.0, 47.0, 28.0, 52.0, 45.0, 46....
# 1  [63.0, 45.0, 52.0, 39.0, 61.0, 57.0, 34.0, 69....
# 2  [34.0, 50.0, 36.0, 30.0, 40.0, 44.0, 63.0, 62....
# 3  [73.0, 47.0, 55.0, 72.0, 69.0, 68.0, 90.0, 81....
# 4  [22.0, 27.0, 40.0, 64.0, 32.0, 51.0, 30.0, 56....
#
#                                       Points_Against  \
# 0  [64.0, 29.0, 43.0, 48.0, 35.0, 39.0, 30.0, 40....
# 1  [25.0, 28.0, 26.0, 73.0, 4.0, 29.0, 55.0, 33.0...
# 2  [65.0, 53.0, 45.0, 38.0, 54.0, 49.0, 32.0, 71....
# 3  [26.0, 29.0, 37.0, 18.0, 56.0, 38.0, 20.0, 15....
# 4  [45.0, 48.0, 48.0, 36.0, 45.0, 28.0, 37.0, 41....
#
#                                            Seed_Game  \
# 0  [True, True, True, True, True, True, True, Tru...
# 1  [True, True, True, True, True, True, True, Tru...
# 2  [True, True, True, True, True, True, True, Tru...
# 3  [True, True, True, True, True, True, True, Tru...
# 4  [True, True, True, True, True, True, True, Tru...
#
#                                         Tourney_Game   wp% Wins Losses  \
# 0  [False, False, False, False, False, False, Fal...  None   10     11
# 1  [False, False, False, False, False, False, Fal...  None   16      5
# 2  [False, False, False, False, False, False, Fal...  None    4     19
# 3  [False, False, False, False, False, False, Fal...  None   20      3
# 4  [False, False, False, False, False, False, Fal...  None   12     10
#
#          w%
# 0  0.476190
# 1  0.761905
# 2  0.173913
# 3  0.869565
# 4  0.545455

# %%
err = wp24_sgo[wp24_sgo.Team == "Campbellsport"]
print(len(err.at[63, "Game_Dates"]))
print(len(err.at[63, "Teams_Played"]))
print(len(err.at[63, "Win"]))
print(len(err.at[63, "Points_For"]))
print(len(err.at[63, "Points_Against"]))
print(len(err.at[63, "Seed_Game"]))
print(len(err.at[63, "Tourney_Game"]))
# Out:
# 24
# 24
# 24
# 24
# 24
# 24
# 24

# %%
print(err.at[63,"Seed_Game"]); print(err.at[63, "Teams_Played"])
# Out:
# [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, False, False, False]
# ['Ozaukee', 'Washington County Home School', 'Mayville', 'Kewaskum', 'North Fond du Lac', 'Omro', 'St. Marys Springs', 'Winnebago Lutheran', 'Winneconne', 'Living Word Lutheran', 'Sheboygan Falls', 'Laconia', 'Mayville', 'Ripon', 'Lomira', 'Omro', 'St. Marys Springs', 'North Fond du Lac', 'Laconia', 'Winnebago Lutheran', 'Oakfield', 'Lomira', 'Milwaukee School of Languages', 'Sheboygan Falls']

# %%
# Get opponent winning percentages
wp_owp_24_sgo = get_opp_winning_percentages(df=wp24_sgo, year=2024, stgco=True)
wp_owp_24_sgo.head()
# Out:
# Calculating opponent win perceentage for: Abbotsford
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Abundant Life Christian/St. Ambrose
# Length of Seed Game Boolean list: 23
# Length of Date of Games List: 23
# Calculating opponent win perceentage for: Adams-Friendship
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Albany/Monticello
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Algoma
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Alma Center Lincoln
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Alma/Pepin
# Length of Seed Game Boolean list: 23
# Length of Date of Games List: 23
# Calculating opponent win perceentage for: Almond-Bancroft
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Altoona
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Amery
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Amherst
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Antigo
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Appleton East
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Appleton North
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Appleton West
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Aquinas
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Arcadia
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Argyle/Pecatonica
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Arrowhead
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Ashland
# Length of Seed Game Boolean list: 23
# Length of Date of Games List: 23
# Calculating opponent win perceentage for: Ashwaubenon
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Assumption
# Length of Seed Game Boolean list: 29
# Length of Date of Games List: 29
# Calculating opponent win perceentage for: Athens
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Auburndale
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Augusta
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Badger
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Baldwin-Woodville
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Bangor
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Baraboo
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Barneveld
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Barron
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Bay Port
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Bayfield
# Length of Seed Game Boolean list: 20
# Length of Date of Games List: 20
# Calculating opponent win perceentage for: Beaver Dam
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Belleville
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Belmont
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Beloit Memorial
# Length of Seed Game Boolean list: 21
# Length of Date of Games List: 21
# Calculating opponent win perceentage for: Benton
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Berlin
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Big Foot
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Birchwood
# Length of Seed Game Boolean list: 23
# Length of Date of Games List: 23
# Calculating opponent win perceentage for: Black Hawk
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Black River Falls
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Blair-Taylor
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Bloomer
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Bonduel
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Boscobel
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Bowler
# Length of Seed Game Boolean list: 22
# Length of Date of Games List: 22
# Calculating opponent win perceentage for: Boyceville
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Brillion
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Brodhead
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Brookfield Academy
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Brookfield Central
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Brookfield East
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Brookwood
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Brown Deer
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Bruce
# Length of Seed Game Boolean list: 23
# Length of Date of Games List: 23
# Calculating opponent win perceentage for: Burlington
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Butternut
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Cadott
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Cambria-Friesland
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Cambridge
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Cameron
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Campbellsport
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Carmen Northwest
# Length of Seed Game Boolean list: 19
# Length of Date of Games List: 19
# Calculating opponent win perceentage for: Cashton
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Catholic Central
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Catholic Memorial
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Cedar Grove-Belgium
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Cedarburg
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Central WI Christian
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Chequamegon
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Chesterton Academy
# Length of Seed Game Boolean list: 20
# Length of Date of Games List: 20
# Calculating opponent win perceentage for: Chetek-Weyerhaeuser
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Chilton
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Chippewa Falls
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Clayton
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Clear Lake
# Length of Seed Game Boolean list: 29
# Length of Date of Games List: 29
# Calculating opponent win perceentage for: Clinton
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Clintonville
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Cochrane-Fountain City
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Colby
# Length of Seed Game Boolean list: 23
# Length of Date of Games List: 23
# Calculating opponent win perceentage for: Coleman
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Colfax
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Columbus
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Columbus Catholic
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Cornell
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Crandon
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Cristo Rey Jesuit
# Length of Seed Game Boolean list: 22
# Length of Date of Games List: 22
# Calculating opponent win perceentage for: Crivitz
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Cuba City
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Cudahy
# Length of Seed Game Boolean list: 22
# Length of Date of Games List: 22
# Calculating opponent win perceentage for: Cumberland
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: D.C. Everest
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Darlington
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: De Pere
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: De Soto
# Length of Seed Game Boolean list: 23
# Length of Date of Games List: 23
# Calculating opponent win perceentage for: DeForest
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Deerfield
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Delavan-Darien
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Denmark
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Destiny
# Length of Seed Game Boolean list: 1
# Length of Date of Games List: 1
# Calculating opponent win perceentage for: Divine Savior Holy Angels
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Dodgeland
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Dodgeville
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Dominican
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Drummond
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Durand-Arkansaw
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: East Troy
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Eastbrook Academy
# Length of Seed Game Boolean list: 17
# Length of Date of Games List: 17
# Calculating opponent win perceentage for: Eau Claire Immanuel Lutheran
# Length of Seed Game Boolean list: 20
# Length of Date of Games List: 20
# Calculating opponent win perceentage for: Eau Claire Memorial
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Eau Claire North
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Edgar
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Edgerton
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Edgewood
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Elcho
# Length of Seed Game Boolean list: 21
# Length of Date of Games List: 21
# Calculating opponent win perceentage for: Eleva-Strum
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Elk Mound
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Elkhart Lake-Glenbeulah
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Elkhorn
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Ellsworth
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Evansville
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Faith Christian (Wms Bay)
# Length of Seed Game Boolean list: 23
# Length of Date of Games List: 23
# Calculating opponent win perceentage for: Fall Creek
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Fall River
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Fennimore
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Flambeau
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Florence
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Fond du Lac
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Fort Atkinson
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Fox Valley Lutheran
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Franklin
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Frederic
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Freedom
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Gale-Ettrick-Trempealeau
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Germantown
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Gibraltar
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Gillett
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Gilman
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Gilmanton
# Length of Seed Game Boolean list: 1
# Length of Date of Games List: 1
# Calculating opponent win perceentage for: Glenwood City
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Golda Meir
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Goodman/Pembine
# Length of Seed Game Boolean list: 22
# Length of Date of Games List: 22
# Calculating opponent win perceentage for: Grafton
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Granton
# Length of Seed Game Boolean list: 1
# Length of Date of Games List: 1
# Calculating opponent win perceentage for: Grantsburg
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Green Bay East
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Green Bay N.E.W. Lutheran/Providence Academy (Green Bay)
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Green Bay Preble
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Green Bay Southwest
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Green Bay West
# Length of Seed Game Boolean list: 1
# Length of Date of Games List: 1
# Calculating opponent win perceentage for: Greendale
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Greenfield
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Greenwood
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Gresham
# Length of Seed Game Boolean list: 23
# Length of Date of Games List: 23
# Calculating opponent win perceentage for: Hamilton
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Hartford
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Hayward
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Heritage Christian
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Highland
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Hilbert
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Hillsboro
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Hmong American Peace
# Length of Seed Game Boolean list: 13
# Length of Date of Games List: 13
# Calculating opponent win perceentage for: Holmen
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Homestead
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Horicon
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Hortonville
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Howards Grove
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Hudson
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Hurley
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Hustisford
# Length of Seed Game Boolean list: 22
# Length of Date of Games List: 22
# Calculating opponent win perceentage for: Independence/Gilmanton
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Iola-Scandinavia
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Iowa-Grant
# Length of Seed Game Boolean list: 23
# Length of Date of Games List: 23
# Calculating opponent win perceentage for: Ithaca
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Janesville Craig
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Janesville Parker
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Jefferson
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Johnson Creek
# Length of Seed Game Boolean list: 23
# Length of Date of Games List: 23
# Calculating opponent win perceentage for: Juda
# Length of Seed Game Boolean list: 20
# Length of Date of Games List: 20
# Calculating opponent win perceentage for: Kaukauna
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Kenosha Bradford
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Kenosha Christian Life
# Length of Seed Game Boolean list: 23
# Length of Date of Games List: 23
# Calculating opponent win perceentage for: Kenosha Indian Trail
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Kenosha St. Joseph Catholic
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Kenosha Tremper
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Kettle Moraine
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Kettle Moraine Lutheran
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Kewaskum
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Kewaunee
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Kickapoo
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Kiel
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Kimberly
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Kohler
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: La Crosse Central
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: La Crosse Logan
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: La Farge/Youth Initiative
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Lac Courte Oreilles
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Laconia
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Ladysmith
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Lake Country Lutheran
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Lake Holcombe
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Lake Mills
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Lakeland
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Lakeside Lutheran
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Lancaster
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Lena
# Length of Seed Game Boolean list: 29
# Length of Date of Games List: 29
# Calculating opponent win perceentage for: Little Chute
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Living Word Lutheran
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Lodi
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Lomira
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Lourdes Acad.
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Loyal
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Luck
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Luther
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Luxemburg-Casco
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Madison Country Day
# Length of Seed Game Boolean list: 12
# Length of Date of Games List: 12
# Calculating opponent win perceentage for: Madison East
# Length of Seed Game Boolean list: 19
# Length of Date of Games List: 19
# Calculating opponent win perceentage for: Madison La Follette
# Length of Seed Game Boolean list: 22
# Length of Date of Games List: 22
# Calculating opponent win perceentage for: Madison Memorial
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Madison West
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Manawa
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Manitowoc Lincoln
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Manitowoc Lutheran
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Marathon
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Marinette
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Marion
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Markesan
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Marshall
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Marshfield
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Martin Luther
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Mauston
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Mayville
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: McDonell Catholic
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: McFarland
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Medford
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Mellen
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Melrose-Mindoro
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Menasha
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Menominee Indian
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Menomonee Falls
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Menomonie
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Mercer
# Length of Seed Game Boolean list: 22
# Length of Date of Games List: 22
# Calculating opponent win perceentage for: Merrill
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Messmer
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Middleton
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Milton
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Milwaukee Academy of Science
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Milwaukee Bay View
# Length of Seed Game Boolean list: 9
# Length of Date of Games List: 9
# Calculating opponent win perceentage for: Milwaukee Bradley Tech/Milwaukee Arts
# Length of Seed Game Boolean list: 23
# Length of Date of Games List: 23
# Calculating opponent win perceentage for: Milwaukee Hamilton/Audubon
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Milwaukee Juneau
# Length of Seed Game Boolean list: 16
# Length of Date of Games List: 16
# Calculating opponent win perceentage for: Milwaukee King
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Milwaukee Lutheran
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Milwaukee Madison
# Length of Seed Game Boolean list: 21
# Length of Date of Games List: 21
# Calculating opponent win perceentage for: Milwaukee Marshall
# Length of Seed Game Boolean list: 6
# Length of Date of Games List: 6
# Calculating opponent win perceentage for: Milwaukee North
# Length of Seed Game Boolean list: 21
# Length of Date of Games List: 21
# Calculating opponent win perceentage for: Milwaukee Pulaski/Carmen South/Carmen Southeast
# Length of Seed Game Boolean list: 1
# Length of Date of Games List: 1
# Calculating opponent win perceentage for: Milwaukee Reagan
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Milwaukee Riverside
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Milwaukee School of Languages
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Milwaukee South
# Length of Seed Game Boolean list: 18
# Length of Date of Games List: 18
# Calculating opponent win perceentage for: Milwaukee Vincent
# Length of Seed Game Boolean list: 18
# Length of Date of Games List: 18
# Calculating opponent win perceentage for: Milwaukee Washington/Fuller Collegiate
# Length of Seed Game Boolean list: 22
# Length of Date of Games List: 22
# Calculating opponent win perceentage for: Mineral Point
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Mishicot
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Mondovi
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Monona Grove
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Monroe
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Montello
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Mosinee
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Mount Horeb
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Mukwonago
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Muskego
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Necedah
# Length of Seed Game Boolean list: 22
# Length of Date of Games List: 22
# Calculating opponent win perceentage for: Neenah
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Neillsville
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Nekoosa
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: New Auburn
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: New Berlin Eisenhower
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: New Berlin West
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: New Glarus
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: New Holstein
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: New Lisbon
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: New London
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: New Richmond
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Newman Catholic
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Niagara
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Nicolet
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: North Crawford
# Length of Seed Game Boolean list: 23
# Length of Date of Games List: 23
# Calculating opponent win perceentage for: North Fond du Lac
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Northland Lutheran
# Length of Seed Game Boolean list: 23
# Length of Date of Games List: 23
# Calculating opponent win perceentage for: Northland Pines
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Northwestern
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Northwood
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Notre Dame
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Oak Creek
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Oakfield
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Obama SCTE
# Length of Seed Game Boolean list: 4
# Length of Date of Games List: 4
# Calculating opponent win perceentage for: Oconomowoc
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Oconto
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Oconto Falls
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Omro
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Onalaska
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Oneida Nation
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Oostburg
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Oregon
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Osceola
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Oshkosh North
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Oshkosh West
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Osseo-Fairchild
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Owen-Withee
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Ozaukee
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Pacelli
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Palmyra-Eagle
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Pardeeville
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Parkview
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Peshtigo
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Pewaukee
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Phelps
# Length of Seed Game Boolean list: 1
# Length of Date of Games List: 1
# Calculating opponent win perceentage for: Phillips
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Pittsville
# Length of Seed Game Boolean list: 29
# Length of Date of Games List: 29
# Calculating opponent win perceentage for: Pius XI Catholic
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Platteville
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Plum City/Elmwood
# Length of Seed Game Boolean list: 22
# Length of Date of Games List: 22
# Calculating opponent win perceentage for: Plymouth
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Port Edwards
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Port Washington
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Portage
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Potosi/Cassville
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Poynette
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Prairie Farm
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Prairie du Chien
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Prentice
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Prescott
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Princeton/Green Lake
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Pulaski
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Racine Case
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Racine Horlick
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Racine Lutheran
# Length of Seed Game Boolean list: 23
# Length of Date of Games List: 23
# Calculating opponent win perceentage for: Racine Park
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Racine St. Catherines
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Randolph
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Random Lake
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Reedsburg
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Reedsville
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Regis
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Rhinelander
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Rib Lake
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Rice Lake
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Richland Center
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Rio
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Ripon
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: River Falls
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: River Ridge
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: River Valley
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Riverdale
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Roncalli
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Rosholt
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Royall
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Saint Anthony
# Length of Seed Game Boolean list: 20
# Length of Date of Games List: 20
# Calculating opponent win perceentage for: Saint Croix Falls
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Saint Francis
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Saint Joan Antida/Tenor/Veritas
# Length of Seed Game Boolean list: 21
# Length of Date of Games List: 21
# Calculating opponent win perceentage for: Saint Mary Catholic
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Saint Thomas Aquinas
# Length of Seed Game Boolean list: 21
# Length of Date of Games List: 21
# Calculating opponent win perceentage for: Saint Thomas More
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Salam
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Sauk Prairie
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Seneca
# Length of Seed Game Boolean list: 20
# Length of Date of Games List: 20
# Calculating opponent win perceentage for: Sevastopol
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Seymour
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Shawano
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Sheboygan Christian
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Sheboygan Falls
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Sheboygan Lutheran
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Sheboygan North
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Sheboygan South
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Shell Lake
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Shiocton
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Shoreland Lutheran
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Shorewood
# Length of Seed Game Boolean list: 22
# Length of Date of Games List: 22
# Calculating opponent win perceentage for: Shullsburg
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Siren
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Slinger
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Solon Springs
# Length of Seed Game Boolean list: 19
# Length of Date of Games List: 19
# Calculating opponent win perceentage for: Somerset
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: South Milwaukee
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: South Shore
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Southern Door
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Southwestern
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Sparta
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Spencer
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Spooner
# Length of Seed Game Boolean list: 23
# Length of Date of Games List: 23
# Calculating opponent win perceentage for: Spring Valley
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: St. Augustine Prep
# Length of Seed Game Boolean list: 22
# Length of Date of Games List: 22
# Calculating opponent win perceentage for: St. Croix Central
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: St. Mary's Springs
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Stanley-Boyd
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Stevens Point
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Stockbridge
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Stoughton
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Stratford
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Sturgeon Bay
# Length of Seed Game Boolean list: 23
# Length of Date of Games List: 23
# Calculating opponent win perceentage for: Sun Prairie East
# Length of Seed Game Boolean list: 23
# Length of Date of Games List: 23
# Calculating opponent win perceentage for: Sun Prairie West
# Length of Seed Game Boolean list: 22
# Length of Date of Games List: 22
# Calculating opponent win perceentage for: Superior
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Suring
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: The Prairie School
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Thorp
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Three Lakes/Phelps
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Tigerton
# Length of Seed Game Boolean list: 1
# Length of Date of Games List: 1
# Calculating opponent win perceentage for: Tomah
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Tomahawk
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Tri-County
# Length of Seed Game Boolean list: 23
# Length of Date of Games List: 23
# Calculating opponent win perceentage for: Turner
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Turtle Lake
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Two Rivers
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Union Grove
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Unity
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: University Lake School Co-op
# Length of Seed Game Boolean list: 19
# Length of Date of Games List: 19
# Calculating opponent win perceentage for: University School of Milwaukee
# Length of Seed Game Boolean list: 17
# Length of Date of Games List: 17
# Calculating opponent win perceentage for: Valders
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Valley Christian (Oshkosh)
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Valley Christian School (Osceola)
# Length of Seed Game Boolean list: 1
# Length of Date of Games List: 1
# Calculating opponent win perceentage for: Verona
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Viroqua
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Wabeno/Laona
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Washburn
# Length of Seed Game Boolean list: 23
# Length of Date of Games List: 23
# Calculating opponent win perceentage for: Washington Island
# Length of Seed Game Boolean list: 1
# Length of Date of Games List: 1
# Calculating opponent win perceentage for: Waterford
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Waterloo
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Watertown
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Watertown Luther Prep
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Waukesha North/Waukesha South
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Waukesha South
# Length of Seed Game Boolean list: 1
# Length of Date of Games List: 1
# Calculating opponent win perceentage for: Waukesha West
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Waunakee
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Waupaca
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Waupun
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Wausau East
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Wausau West
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Wausaukee
# Length of Seed Game Boolean list: 23
# Length of Date of Games List: 23
# Calculating opponent win perceentage for: Wautoma
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Wauwatosa East
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Wauwatosa West
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Wauzeka-Steuben
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Wayland Academy
# Length of Seed Game Boolean list: 23
# Length of Date of Games List: 23
# Calculating opponent win perceentage for: Webster
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: West Allis Central
# Length of Seed Game Boolean list: 23
# Length of Date of Games List: 23
# Calculating opponent win perceentage for: West Allis Hale
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: West Bend East
# Length of Seed Game Boolean list: 5
# Length of Date of Games List: 5
# Calculating opponent win perceentage for: West Bend West
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: West De Pere
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: West Salem
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Westby
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Westfield
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Weston
# Length of Seed Game Boolean list: 1
# Length of Date of Games List: 1
# Calculating opponent win perceentage for: Westosha Central
# Length of Seed Game Boolean list: 23
# Length of Date of Games List: 23
# Calculating opponent win perceentage for: Weyauwega-Fremont
# Length of Seed Game Boolean list: 23
# Length of Date of Games List: 23
# Calculating opponent win perceentage for: White Lake
# Length of Seed Game Boolean list: 10
# Length of Date of Games List: 10
# Calculating opponent win perceentage for: Whitefish Bay
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Whitehall
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Whitewater
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Whitnall
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Wild Rose
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Williams Bay
# Length of Seed Game Boolean list: 23
# Length of Date of Games List: 23
# Calculating opponent win perceentage for: Wilmot
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Winnebago Lutheran
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Winneconne
# Length of Seed Game Boolean list: 27
# Length of Date of Games List: 27
# Calculating opponent win perceentage for: Winter
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Wisconsin Dells
# Length of Seed Game Boolean list: 26
# Length of Date of Games List: 26
# Calculating opponent win perceentage for: Wisconsin Heights
# Length of Seed Game Boolean list: 22
# Length of Date of Games List: 22
# Calculating opponent win perceentage for: Wisconsin Lutheran
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Wisconsin Rapids Lincoln
# Length of Seed Game Boolean list: 25
# Length of Date of Games List: 25
# Calculating opponent win perceentage for: Wittenberg-Birnamwood
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Wonewoc-Center
# Length of Seed Game Boolean list: 22
# Length of Date of Games List: 22
# Calculating opponent win perceentage for: Wrightstown
# Length of Seed Game Boolean list: 24
# Length of Date of Games List: 24
# Calculating opponent win perceentage for: Xavier
# Length of Seed Game Boolean list: 28
# Length of Date of Games List: 28
# Calculating opponent win perceentage for: Young Coggs
# Length of Seed Game Boolean list: 1
# Length of Date of Games List: 1
#                                   Team  \
# 0                           Abbotsford
# 1  Abundant Life Christian/St. Ambrose
# 2                     Adams-Friendship
# 3                    Albany/Monticello
# 4                               Algoma
#
#                                           Game_Dates  \
# 0  [2023-11-16 00:00:00, 2023-11-20 00:00:00, 202...
# 1  [2023-11-14 00:00:00, 2023-11-16 00:00:00, 202...
# 2  [2023-11-14 00:00:00, 2023-11-16 00:00:00, 202...
# 3  [2023-11-14 00:00:00, 2023-11-16 00:00:00, 202...
# 4  [2023-11-14 00:00:00, 2023-11-16 00:00:00, 202...
#
#                                         Teams_Played  \
# 0  [Athens, Colby, Prentice, Greenwood, Auburndal...
# 1  [Juda, Central WI Christian, Parkview, Argyle/...
# 2  [Cambridge, Poynette, Marshall, Amherst, Tomah...
# 3  [Benton, Turner, Belleville, Williams Bay, Bel...
# 4  [Bonduel, Freedom, Mishicot, Green Bay N.E.W. ...
#
#                                                  Win  \
# 0  [False, True, False, False, False, True, True,...
# 1  [True, True, True, False, True, True, False, T...
# 2  [False, False, False, False, False, False, Tru...
# 3  [True, True, True, True, True, True, True, Tru...
# 4  [False, False, False, True, False, True, False...
#
#                                           Points_For  \
# 0  [42.0, 69.0, 36.0, 47.0, 28.0, 52.0, 45.0, 46....
# 1  [63.0, 45.0, 52.0, 39.0, 61.0, 57.0, 34.0, 69....
# 2  [34.0, 50.0, 36.0, 30.0, 40.0, 44.0, 63.0, 62....
# 3  [73.0, 47.0, 55.0, 72.0, 69.0, 68.0, 90.0, 81....
# 4  [22.0, 27.0, 40.0, 64.0, 32.0, 51.0, 30.0, 56....
#
#                                       Points_Against  \
# 0  [64.0, 29.0, 43.0, 48.0, 35.0, 39.0, 30.0, 40....
# 1  [25.0, 28.0, 26.0, 73.0, 4.0, 29.0, 55.0, 33.0...
# 2  [65.0, 53.0, 45.0, 38.0, 54.0, 49.0, 32.0, 71....
# 3  [26.0, 29.0, 37.0, 18.0, 56.0, 38.0, 20.0, 15....
# 4  [45.0, 48.0, 48.0, 36.0, 45.0, 28.0, 37.0, 41....
#
#                                            Seed_Game  \
# 0  [True, True, True, True, True, True, True, Tru...
# 1  [True, True, True, True, True, True, True, Tru...
# 2  [True, True, True, True, True, True, True, Tru...
# 3  [True, True, True, True, True, True, True, Tru...
# 4  [True, True, True, True, True, True, True, Tru...
#
#                                         Tourney_Game   wp% Wins Losses  \
# 0  [False, False, False, False, False, False, Fal...  None   10     11
# 1  [False, False, False, False, False, False, Fal...  None   16      5
# 2  [False, False, False, False, False, False, Fal...  None    4     19
# 3  [False, False, False, False, False, False, Fal...  None   20      3
# 4  [False, False, False, False, False, False, Fal...  None   12     10
#
#          w%  Opponent_Wins  Opponent_Losses  Defeated_Opponent_Wins  \
# 0  0.476190          238.0            223.0                    78.0
# 1  0.761905          169.0            246.0                    97.0
# 2  0.173913          292.0            215.0                    23.0
# 3  0.869565          221.0            260.0                   165.0
# 4  0.545455          230.0            247.0                    74.0
#
#    Defeated_Opponent_Losses       ow%      dow%
# 0                     141.0  0.516269  0.356164
# 1                     209.0  0.407229  0.316993
# 2                      64.0  0.575937  0.264368
# 3                     253.0  0.459459  0.394737
# 4                     186.0  0.482180  0.284615

# %%
wp_owp_oowp_24 = get_opp_opp_winning_percentages(df=wp_owp_24_sgo, year=2024)
wp_owp_oowp_24.head()
# Out:
# Calculating opponents' opponents' win percentage for team: Abbotsford
# Calculating opponents' opponents' win percentage for team: Abundant Life Christian/St. Ambrose
# Calculating opponents' opponents' win percentage for team: Adams-Friendship
# Calculating opponents' opponents' win percentage for team: Albany/Monticello
# Calculating opponents' opponents' win percentage for team: Algoma
# Calculating opponents' opponents' win percentage for team: Alma Center Lincoln
# Calculating opponents' opponents' win percentage for team: Alma/Pepin
# Calculating opponents' opponents' win percentage for team: Almond-Bancroft
# Calculating opponents' opponents' win percentage for team: Altoona
# Calculating opponents' opponents' win percentage for team: Amery
# Calculating opponents' opponents' win percentage for team: Amherst
# Calculating opponents' opponents' win percentage for team: Antigo
# Calculating opponents' opponents' win percentage for team: Appleton East
# Calculating opponents' opponents' win percentage for team: Appleton North
# Calculating opponents' opponents' win percentage for team: Appleton West
# Calculating opponents' opponents' win percentage for team: Aquinas
# Calculating opponents' opponents' win percentage for team: Arcadia
# Calculating opponents' opponents' win percentage for team: Argyle/Pecatonica
# Calculating opponents' opponents' win percentage for team: Arrowhead
# Calculating opponents' opponents' win percentage for team: Ashland
# Calculating opponents' opponents' win percentage for team: Ashwaubenon
# Calculating opponents' opponents' win percentage for team: Assumption
# Calculating opponents' opponents' win percentage for team: Athens
# Calculating opponents' opponents' win percentage for team: Auburndale
# Calculating opponents' opponents' win percentage for team: Augusta
# Calculating opponents' opponents' win percentage for team: Badger
# Calculating opponents' opponents' win percentage for team: Baldwin-Woodville
# Calculating opponents' opponents' win percentage for team: Bangor
# Calculating opponents' opponents' win percentage for team: Baraboo
# Calculating opponents' opponents' win percentage for team: Barneveld
# Calculating opponents' opponents' win percentage for team: Barron
# Calculating opponents' opponents' win percentage for team: Bay Port
# Calculating opponents' opponents' win percentage for team: Bayfield
# Calculating opponents' opponents' win percentage for team: Beaver Dam
# Calculating opponents' opponents' win percentage for team: Belleville
# Calculating opponents' opponents' win percentage for team: Belmont
# Calculating opponents' opponents' win percentage for team: Beloit Memorial
# Calculating opponents' opponents' win percentage for team: Benton
# Calculating opponents' opponents' win percentage for team: Berlin
# Calculating opponents' opponents' win percentage for team: Big Foot
# Calculating opponents' opponents' win percentage for team: Birchwood
# Calculating opponents' opponents' win percentage for team: Black Hawk
# Calculating opponents' opponents' win percentage for team: Black River Falls
# Calculating opponents' opponents' win percentage for team: Blair-Taylor
# Calculating opponents' opponents' win percentage for team: Bloomer
# Calculating opponents' opponents' win percentage for team: Bonduel
# Calculating opponents' opponents' win percentage for team: Boscobel
# Calculating opponents' opponents' win percentage for team: Bowler
# Calculating opponents' opponents' win percentage for team: Boyceville
# Calculating opponents' opponents' win percentage for team: Brillion
# Calculating opponents' opponents' win percentage for team: Brodhead
# Calculating opponents' opponents' win percentage for team: Brookfield Academy
# Calculating opponents' opponents' win percentage for team: Brookfield Central
# Calculating opponents' opponents' win percentage for team: Brookfield East
# Calculating opponents' opponents' win percentage for team: Brookwood
# Calculating opponents' opponents' win percentage for team: Brown Deer
# Calculating opponents' opponents' win percentage for team: Bruce
# Calculating opponents' opponents' win percentage for team: Burlington
# Calculating opponents' opponents' win percentage for team: Butternut
# Calculating opponents' opponents' win percentage for team: Cadott
# Calculating opponents' opponents' win percentage for team: Cambria-Friesland
# Calculating opponents' opponents' win percentage for team: Cambridge
# Calculating opponents' opponents' win percentage for team: Cameron
# Calculating opponents' opponents' win percentage for team: Campbellsport
# Calculating opponents' opponents' win percentage for team: Carmen Northwest
# Calculating opponents' opponents' win percentage for team: Cashton
# Calculating opponents' opponents' win percentage for team: Catholic Central
# Calculating opponents' opponents' win percentage for team: Catholic Memorial
# Calculating opponents' opponents' win percentage for team: Cedar Grove-Belgium
# Calculating opponents' opponents' win percentage for team: Cedarburg
# Calculating opponents' opponents' win percentage for team: Central WI Christian
# Calculating opponents' opponents' win percentage for team: Chequamegon
# Calculating opponents' opponents' win percentage for team: Chesterton Academy
# Calculating opponents' opponents' win percentage for team: Chetek-Weyerhaeuser
# Calculating opponents' opponents' win percentage for team: Chilton
# Calculating opponents' opponents' win percentage for team: Chippewa Falls
# Calculating opponents' opponents' win percentage for team: Clayton
# Calculating opponents' opponents' win percentage for team: Clear Lake
# Calculating opponents' opponents' win percentage for team: Clinton
# Calculating opponents' opponents' win percentage for team: Clintonville
# Calculating opponents' opponents' win percentage for team: Cochrane-Fountain City
# Calculating opponents' opponents' win percentage for team: Colby
# Calculating opponents' opponents' win percentage for team: Coleman
# Calculating opponents' opponents' win percentage for team: Colfax
# Calculating opponents' opponents' win percentage for team: Columbus
# Calculating opponents' opponents' win percentage for team: Columbus Catholic
# Calculating opponents' opponents' win percentage for team: Cornell
# Calculating opponents' opponents' win percentage for team: Crandon
# Calculating opponents' opponents' win percentage for team: Cristo Rey Jesuit
# Calculating opponents' opponents' win percentage for team: Crivitz
# Calculating opponents' opponents' win percentage for team: Cuba City
# Calculating opponents' opponents' win percentage for team: Cudahy
# Calculating opponents' opponents' win percentage for team: Cumberland
# Calculating opponents' opponents' win percentage for team: D.C. Everest
# Calculating opponents' opponents' win percentage for team: Darlington
# Calculating opponents' opponents' win percentage for team: De Pere
# Calculating opponents' opponents' win percentage for team: De Soto
# Calculating opponents' opponents' win percentage for team: DeForest
# Calculating opponents' opponents' win percentage for team: Deerfield
# Calculating opponents' opponents' win percentage for team: Delavan-Darien
# Calculating opponents' opponents' win percentage for team: Denmark
# Calculating opponents' opponents' win percentage for team: Destiny
# Calculating opponents' opponents' win percentage for team: Divine Savior Holy Angels
# Calculating opponents' opponents' win percentage for team: Dodgeland
# Calculating opponents' opponents' win percentage for team: Dodgeville
# Calculating opponents' opponents' win percentage for team: Dominican
# Calculating opponents' opponents' win percentage for team: Drummond
# Calculating opponents' opponents' win percentage for team: Durand-Arkansaw
# Calculating opponents' opponents' win percentage for team: East Troy
# Calculating opponents' opponents' win percentage for team: Eastbrook Academy
# Calculating opponents' opponents' win percentage for team: Eau Claire Immanuel Lutheran
# Calculating opponents' opponents' win percentage for team: Eau Claire Memorial
# Calculating opponents' opponents' win percentage for team: Eau Claire North
# Calculating opponents' opponents' win percentage for team: Edgar
# Calculating opponents' opponents' win percentage for team: Edgerton
# Calculating opponents' opponents' win percentage for team: Edgewood
# Calculating opponents' opponents' win percentage for team: Elcho
# Calculating opponents' opponents' win percentage for team: Eleva-Strum
# Calculating opponents' opponents' win percentage for team: Elk Mound
# Calculating opponents' opponents' win percentage for team: Elkhart Lake-Glenbeulah
# Calculating opponents' opponents' win percentage for team: Elkhorn
# Calculating opponents' opponents' win percentage for team: Ellsworth
# Calculating opponents' opponents' win percentage for team: Evansville
# Calculating opponents' opponents' win percentage for team: Faith Christian (Wms Bay)
# Calculating opponents' opponents' win percentage for team: Fall Creek
# Calculating opponents' opponents' win percentage for team: Fall River
# Calculating opponents' opponents' win percentage for team: Fennimore
# Calculating opponents' opponents' win percentage for team: Flambeau
# Calculating opponents' opponents' win percentage for team: Florence
# Calculating opponents' opponents' win percentage for team: Fond du Lac
# Calculating opponents' opponents' win percentage for team: Fort Atkinson
# Calculating opponents' opponents' win percentage for team: Fox Valley Lutheran
# Calculating opponents' opponents' win percentage for team: Franklin
# Calculating opponents' opponents' win percentage for team: Frederic
# Calculating opponents' opponents' win percentage for team: Freedom
# Calculating opponents' opponents' win percentage for team: Gale-Ettrick-Trempealeau
# Calculating opponents' opponents' win percentage for team: Germantown
# Calculating opponents' opponents' win percentage for team: Gibraltar
# Calculating opponents' opponents' win percentage for team: Gillett
# Calculating opponents' opponents' win percentage for team: Gilman
# Calculating opponents' opponents' win percentage for team: Gilmanton
# Calculating opponents' opponents' win percentage for team: Glenwood City
# Calculating opponents' opponents' win percentage for team: Golda Meir
# Calculating opponents' opponents' win percentage for team: Goodman/Pembine
# Calculating opponents' opponents' win percentage for team: Grafton
# Calculating opponents' opponents' win percentage for team: Granton
# Calculating opponents' opponents' win percentage for team: Grantsburg
# Calculating opponents' opponents' win percentage for team: Green Bay East
# Calculating opponents' opponents' win percentage for team: Green Bay N.E.W. Lutheran/Providence Academy (Green Bay)
# Calculating opponents' opponents' win percentage for team: Green Bay Preble
# Calculating opponents' opponents' win percentage for team: Green Bay Southwest
# Calculating opponents' opponents' win percentage for team: Green Bay West
# Calculating opponents' opponents' win percentage for team: Greendale
# Calculating opponents' opponents' win percentage for team: Greenfield
# Calculating opponents' opponents' win percentage for team: Greenwood
# Calculating opponents' opponents' win percentage for team: Gresham
# Calculating opponents' opponents' win percentage for team: Hamilton
# Calculating opponents' opponents' win percentage for team: Hartford
# Calculating opponents' opponents' win percentage for team: Hayward
# Calculating opponents' opponents' win percentage for team: Heritage Christian
# Calculating opponents' opponents' win percentage for team: Highland
# Calculating opponents' opponents' win percentage for team: Hilbert
# Calculating opponents' opponents' win percentage for team: Hillsboro
# Calculating opponents' opponents' win percentage for team: Hmong American Peace
# Calculating opponents' opponents' win percentage for team: Holmen
# Calculating opponents' opponents' win percentage for team: Homestead
# Calculating opponents' opponents' win percentage for team: Horicon
# Calculating opponents' opponents' win percentage for team: Hortonville
# Calculating opponents' opponents' win percentage for team: Howards Grove
# Calculating opponents' opponents' win percentage for team: Hudson
# Calculating opponents' opponents' win percentage for team: Hurley
# Calculating opponents' opponents' win percentage for team: Hustisford
# Calculating opponents' opponents' win percentage for team: Independence/Gilmanton
# Calculating opponents' opponents' win percentage for team: Iola-Scandinavia
# Calculating opponents' opponents' win percentage for team: Iowa-Grant
# Calculating opponents' opponents' win percentage for team: Ithaca
# Calculating opponents' opponents' win percentage for team: Janesville Craig
# Calculating opponents' opponents' win percentage for team: Janesville Parker
# Calculating opponents' opponents' win percentage for team: Jefferson
# Calculating opponents' opponents' win percentage for team: Johnson Creek
# Calculating opponents' opponents' win percentage for team: Juda
# Calculating opponents' opponents' win percentage for team: Kaukauna
# Calculating opponents' opponents' win percentage for team: Kenosha Bradford
# Calculating opponents' opponents' win percentage for team: Kenosha Christian Life
# Calculating opponents' opponents' win percentage for team: Kenosha Indian Trail
# Calculating opponents' opponents' win percentage for team: Kenosha St. Joseph Catholic
# Calculating opponents' opponents' win percentage for team: Kenosha Tremper
# Calculating opponents' opponents' win percentage for team: Kettle Moraine
# Calculating opponents' opponents' win percentage for team: Kettle Moraine Lutheran
# Calculating opponents' opponents' win percentage for team: Kewaskum
# Calculating opponents' opponents' win percentage for team: Kewaunee
# Calculating opponents' opponents' win percentage for team: Kickapoo
# Calculating opponents' opponents' win percentage for team: Kiel
# Calculating opponents' opponents' win percentage for team: Kimberly
# Calculating opponents' opponents' win percentage for team: Kohler
# Calculating opponents' opponents' win percentage for team: La Crosse Central
# Calculating opponents' opponents' win percentage for team: La Crosse Logan
# Calculating opponents' opponents' win percentage for team: La Farge/Youth Initiative
# Calculating opponents' opponents' win percentage for team: Lac Courte Oreilles
# Calculating opponents' opponents' win percentage for team: Laconia
# Calculating opponents' opponents' win percentage for team: Ladysmith
# Calculating opponents' opponents' win percentage for team: Lake Country Lutheran
# Calculating opponents' opponents' win percentage for team: Lake Holcombe
# Calculating opponents' opponents' win percentage for team: Lake Mills
# Calculating opponents' opponents' win percentage for team: Lakeland
# Calculating opponents' opponents' win percentage for team: Lakeside Lutheran
# Calculating opponents' opponents' win percentage for team: Lancaster
# Calculating opponents' opponents' win percentage for team: Lena
# Calculating opponents' opponents' win percentage for team: Little Chute
# Calculating opponents' opponents' win percentage for team: Living Word Lutheran
# Calculating opponents' opponents' win percentage for team: Lodi
# Calculating opponents' opponents' win percentage for team: Lomira
# Calculating opponents' opponents' win percentage for team: Lourdes Acad.
# Calculating opponents' opponents' win percentage for team: Loyal
# Calculating opponents' opponents' win percentage for team: Luck
# Calculating opponents' opponents' win percentage for team: Luther
# Calculating opponents' opponents' win percentage for team: Luxemburg-Casco
# Calculating opponents' opponents' win percentage for team: Madison Country Day
# Calculating opponents' opponents' win percentage for team: Madison East
# Calculating opponents' opponents' win percentage for team: Madison La Follette
# Calculating opponents' opponents' win percentage for team: Madison Memorial
# Calculating opponents' opponents' win percentage for team: Madison West
# Calculating opponents' opponents' win percentage for team: Manawa
# Calculating opponents' opponents' win percentage for team: Manitowoc Lincoln
# Calculating opponents' opponents' win percentage for team: Manitowoc Lutheran
# Calculating opponents' opponents' win percentage for team: Marathon
# Calculating opponents' opponents' win percentage for team: Marinette
# Calculating opponents' opponents' win percentage for team: Marion
# Calculating opponents' opponents' win percentage for team: Markesan
# Calculating opponents' opponents' win percentage for team: Marshall
# Calculating opponents' opponents' win percentage for team: Marshfield
# Calculating opponents' opponents' win percentage for team: Martin Luther
# Calculating opponents' opponents' win percentage for team: Mauston
# Calculating opponents' opponents' win percentage for team: Mayville
# Calculating opponents' opponents' win percentage for team: McDonell Catholic
# Calculating opponents' opponents' win percentage for team: McFarland
# Calculating opponents' opponents' win percentage for team: Medford
# Calculating opponents' opponents' win percentage for team: Mellen
# Calculating opponents' opponents' win percentage for team: Melrose-Mindoro
# Calculating opponents' opponents' win percentage for team: Menasha
# Calculating opponents' opponents' win percentage for team: Menominee Indian
# Calculating opponents' opponents' win percentage for team: Menomonee Falls
# Calculating opponents' opponents' win percentage for team: Menomonie
# Calculating opponents' opponents' win percentage for team: Mercer
# Calculating opponents' opponents' win percentage for team: Merrill
# Calculating opponents' opponents' win percentage for team: Messmer
# Calculating opponents' opponents' win percentage for team: Middleton
# Calculating opponents' opponents' win percentage for team: Milton
# Calculating opponents' opponents' win percentage for team: Milwaukee Academy of Science
# Calculating opponents' opponents' win percentage for team: Milwaukee Bay View
# Calculating opponents' opponents' win percentage for team: Milwaukee Bradley Tech/Milwaukee Arts
# Calculating opponents' opponents' win percentage for team: Milwaukee Hamilton/Audubon
# Calculating opponents' opponents' win percentage for team: Milwaukee Juneau
# Calculating opponents' opponents' win percentage for team: Milwaukee King
# Calculating opponents' opponents' win percentage for team: Milwaukee Lutheran
# Calculating opponents' opponents' win percentage for team: Milwaukee Madison
# Calculating opponents' opponents' win percentage for team: Milwaukee Marshall
# Calculating opponents' opponents' win percentage for team: Milwaukee North
# Calculating opponents' opponents' win percentage for team: Milwaukee Pulaski/Carmen South/Carmen Southeast
# Calculating opponents' opponents' win percentage for team: Milwaukee Reagan
# Calculating opponents' opponents' win percentage for team: Milwaukee Riverside
# Calculating opponents' opponents' win percentage for team: Milwaukee School of Languages
# Calculating opponents' opponents' win percentage for team: Milwaukee South
# Calculating opponents' opponents' win percentage for team: Milwaukee Vincent
# Calculating opponents' opponents' win percentage for team: Milwaukee Washington/Fuller Collegiate
# Calculating opponents' opponents' win percentage for team: Mineral Point
# Calculating opponents' opponents' win percentage for team: Mishicot
# Calculating opponents' opponents' win percentage for team: Mondovi
# Calculating opponents' opponents' win percentage for team: Monona Grove
# Calculating opponents' opponents' win percentage for team: Monroe
# Calculating opponents' opponents' win percentage for team: Montello
# Calculating opponents' opponents' win percentage for team: Mosinee
# Calculating opponents' opponents' win percentage for team: Mount Horeb
# Calculating opponents' opponents' win percentage for team: Mukwonago
# Calculating opponents' opponents' win percentage for team: Muskego
# Calculating opponents' opponents' win percentage for team: Necedah
# Calculating opponents' opponents' win percentage for team: Neenah
# Calculating opponents' opponents' win percentage for team: Neillsville
# Calculating opponents' opponents' win percentage for team: Nekoosa
# Calculating opponents' opponents' win percentage for team: New Auburn
# Calculating opponents' opponents' win percentage for team: New Berlin Eisenhower
# Calculating opponents' opponents' win percentage for team: New Berlin West
# Calculating opponents' opponents' win percentage for team: New Glarus
# Calculating opponents' opponents' win percentage for team: New Holstein
# Calculating opponents' opponents' win percentage for team: New Lisbon
# Calculating opponents' opponents' win percentage for team: New London
# Calculating opponents' opponents' win percentage for team: New Richmond
# Calculating opponents' opponents' win percentage for team: Newman Catholic
# Calculating opponents' opponents' win percentage for team: Niagara
# Calculating opponents' opponents' win percentage for team: Nicolet
# Calculating opponents' opponents' win percentage for team: North Crawford
# Calculating opponents' opponents' win percentage for team: North Fond du Lac
# Calculating opponents' opponents' win percentage for team: Northland Lutheran
# Calculating opponents' opponents' win percentage for team: Northland Pines
# Calculating opponents' opponents' win percentage for team: Northwestern
# Calculating opponents' opponents' win percentage for team: Northwood
# Calculating opponents' opponents' win percentage for team: Notre Dame
# Calculating opponents' opponents' win percentage for team: Oak Creek
# Calculating opponents' opponents' win percentage for team: Oakfield
# Calculating opponents' opponents' win percentage for team: Obama SCTE
# Calculating opponents' opponents' win percentage for team: Oconomowoc
# Calculating opponents' opponents' win percentage for team: Oconto
# Calculating opponents' opponents' win percentage for team: Oconto Falls
# Calculating opponents' opponents' win percentage for team: Omro
# Calculating opponents' opponents' win percentage for team: Onalaska
# Calculating opponents' opponents' win percentage for team: Oneida Nation
# Calculating opponents' opponents' win percentage for team: Oostburg
# Calculating opponents' opponents' win percentage for team: Oregon
# Calculating opponents' opponents' win percentage for team: Osceola
# Calculating opponents' opponents' win percentage for team: Oshkosh North
# Calculating opponents' opponents' win percentage for team: Oshkosh West
# Calculating opponents' opponents' win percentage for team: Osseo-Fairchild
# Calculating opponents' opponents' win percentage for team: Owen-Withee
# Calculating opponents' opponents' win percentage for team: Ozaukee
# Calculating opponents' opponents' win percentage for team: Pacelli
# Calculating opponents' opponents' win percentage for team: Palmyra-Eagle
# Calculating opponents' opponents' win percentage for team: Pardeeville
# Calculating opponents' opponents' win percentage for team: Parkview
# Calculating opponents' opponents' win percentage for team: Peshtigo
# Calculating opponents' opponents' win percentage for team: Pewaukee
# Calculating opponents' opponents' win percentage for team: Phelps
# Calculating opponents' opponents' win percentage for team: Phillips
# Calculating opponents' opponents' win percentage for team: Pittsville
# Calculating opponents' opponents' win percentage for team: Pius XI Catholic
# Calculating opponents' opponents' win percentage for team: Platteville
# Calculating opponents' opponents' win percentage for team: Plum City/Elmwood
# Calculating opponents' opponents' win percentage for team: Plymouth
# Calculating opponents' opponents' win percentage for team: Port Edwards
# Calculating opponents' opponents' win percentage for team: Port Washington
# Calculating opponents' opponents' win percentage for team: Portage
# Calculating opponents' opponents' win percentage for team: Potosi/Cassville
# Calculating opponents' opponents' win percentage for team: Poynette
# Calculating opponents' opponents' win percentage for team: Prairie Farm
# Calculating opponents' opponents' win percentage for team: Prairie du Chien
# Calculating opponents' opponents' win percentage for team: Prentice
# Calculating opponents' opponents' win percentage for team: Prescott
# Calculating opponents' opponents' win percentage for team: Princeton/Green Lake
# Calculating opponents' opponents' win percentage for team: Pulaski
# Calculating opponents' opponents' win percentage for team: Racine Case
# Calculating opponents' opponents' win percentage for team: Racine Horlick
# Calculating opponents' opponents' win percentage for team: Racine Lutheran
# Calculating opponents' opponents' win percentage for team: Racine Park
# Calculating opponents' opponents' win percentage for team: Racine St. Catherines
# Calculating opponents' opponents' win percentage for team: Randolph
# Calculating opponents' opponents' win percentage for team: Random Lake
# Calculating opponents' opponents' win percentage for team: Reedsburg
# Calculating opponents' opponents' win percentage for team: Reedsville
# Calculating opponents' opponents' win percentage for team: Regis
# Calculating opponents' opponents' win percentage for team: Rhinelander
# Calculating opponents' opponents' win percentage for team: Rib Lake
# Calculating opponents' opponents' win percentage for team: Rice Lake
# Calculating opponents' opponents' win percentage for team: Richland Center
# Calculating opponents' opponents' win percentage for team: Rio
# Calculating opponents' opponents' win percentage for team: Ripon
# Calculating opponents' opponents' win percentage for team: River Falls
# Calculating opponents' opponents' win percentage for team: River Ridge
# Calculating opponents' opponents' win percentage for team: River Valley
# Calculating opponents' opponents' win percentage for team: Riverdale
# Calculating opponents' opponents' win percentage for team: Roncalli
# Calculating opponents' opponents' win percentage for team: Rosholt
# Calculating opponents' opponents' win percentage for team: Royall
# Calculating opponents' opponents' win percentage for team: Saint Anthony
# Calculating opponents' opponents' win percentage for team: Saint Croix Falls
# Calculating opponents' opponents' win percentage for team: Saint Francis
# Calculating opponents' opponents' win percentage for team: Saint Joan Antida/Tenor/Veritas
# Calculating opponents' opponents' win percentage for team: Saint Mary Catholic
# Calculating opponents' opponents' win percentage for team: Saint Thomas Aquinas
# Calculating opponents' opponents' win percentage for team: Saint Thomas More
# Calculating opponents' opponents' win percentage for team: Salam
# Calculating opponents' opponents' win percentage for team: Sauk Prairie
# Calculating opponents' opponents' win percentage for team: Seneca
# Calculating opponents' opponents' win percentage for team: Sevastopol
# Calculating opponents' opponents' win percentage for team: Seymour
# Calculating opponents' opponents' win percentage for team: Shawano
# Calculating opponents' opponents' win percentage for team: Sheboygan Christian
# Calculating opponents' opponents' win percentage for team: Sheboygan Falls
# Calculating opponents' opponents' win percentage for team: Sheboygan Lutheran
# Calculating opponents' opponents' win percentage for team: Sheboygan North
# Calculating opponents' opponents' win percentage for team: Sheboygan South
# Calculating opponents' opponents' win percentage for team: Shell Lake
# Calculating opponents' opponents' win percentage for team: Shiocton
# Calculating opponents' opponents' win percentage for team: Shoreland Lutheran
# Calculating opponents' opponents' win percentage for team: Shorewood
# Calculating opponents' opponents' win percentage for team: Shullsburg
# Calculating opponents' opponents' win percentage for team: Siren
# Calculating opponents' opponents' win percentage for team: Slinger
# Calculating opponents' opponents' win percentage for team: Solon Springs
# Calculating opponents' opponents' win percentage for team: Somerset
# Calculating opponents' opponents' win percentage for team: South Milwaukee
# Calculating opponents' opponents' win percentage for team: South Shore
# Calculating opponents' opponents' win percentage for team: Southern Door
# Calculating opponents' opponents' win percentage for team: Southwestern
# Calculating opponents' opponents' win percentage for team: Sparta
# Calculating opponents' opponents' win percentage for team: Spencer
# Calculating opponents' opponents' win percentage for team: Spooner
# Calculating opponents' opponents' win percentage for team: Spring Valley
# Calculating opponents' opponents' win percentage for team: St. Augustine Prep
# Calculating opponents' opponents' win percentage for team: St. Croix Central
# Calculating opponents' opponents' win percentage for team: St. Mary's Springs
# Calculating opponents' opponents' win percentage for team: Stanley-Boyd
# Calculating opponents' opponents' win percentage for team: Stevens Point
# Calculating opponents' opponents' win percentage for team: Stockbridge
# Calculating opponents' opponents' win percentage for team: Stoughton
# Calculating opponents' opponents' win percentage for team: Stratford
# Calculating opponents' opponents' win percentage for team: Sturgeon Bay
# Calculating opponents' opponents' win percentage for team: Sun Prairie East
# Calculating opponents' opponents' win percentage for team: Sun Prairie West
# Calculating opponents' opponents' win percentage for team: Superior
# Calculating opponents' opponents' win percentage for team: Suring
# Calculating opponents' opponents' win percentage for team: The Prairie School
# Calculating opponents' opponents' win percentage for team: Thorp
# Calculating opponents' opponents' win percentage for team: Three Lakes/Phelps
# Calculating opponents' opponents' win percentage for team: Tigerton
# Calculating opponents' opponents' win percentage for team: Tomah
# Calculating opponents' opponents' win percentage for team: Tomahawk
# Calculating opponents' opponents' win percentage for team: Tri-County
# Calculating opponents' opponents' win percentage for team: Turner
# Calculating opponents' opponents' win percentage for team: Turtle Lake
# Calculating opponents' opponents' win percentage for team: Two Rivers
# Calculating opponents' opponents' win percentage for team: Union Grove
# Calculating opponents' opponents' win percentage for team: Unity
# Calculating opponents' opponents' win percentage for team: University Lake School Co-op
# Calculating opponents' opponents' win percentage for team: University School of Milwaukee
# Calculating opponents' opponents' win percentage for team: Valders
# Calculating opponents' opponents' win percentage for team: Valley Christian (Oshkosh)
# Calculating opponents' opponents' win percentage for team: Valley Christian School (Osceola)
# Calculating opponents' opponents' win percentage for team: Verona
# Calculating opponents' opponents' win percentage for team: Viroqua
# Calculating opponents' opponents' win percentage for team: Wabeno/Laona
# Calculating opponents' opponents' win percentage for team: Washburn
# Calculating opponents' opponents' win percentage for team: Washington Island
# Calculating opponents' opponents' win percentage for team: Waterford
# Calculating opponents' opponents' win percentage for team: Waterloo
# Calculating opponents' opponents' win percentage for team: Watertown
# Calculating opponents' opponents' win percentage for team: Watertown Luther Prep
# Calculating opponents' opponents' win percentage for team: Waukesha North/Waukesha South
# Calculating opponents' opponents' win percentage for team: Waukesha South
# Calculating opponents' opponents' win percentage for team: Waukesha West
# Calculating opponents' opponents' win percentage for team: Waunakee
# Calculating opponents' opponents' win percentage for team: Waupaca
# Calculating opponents' opponents' win percentage for team: Waupun
# Calculating opponents' opponents' win percentage for team: Wausau East
# Calculating opponents' opponents' win percentage for team: Wausau West
# Calculating opponents' opponents' win percentage for team: Wausaukee
# Calculating opponents' opponents' win percentage for team: Wautoma
# Calculating opponents' opponents' win percentage for team: Wauwatosa East
# Calculating opponents' opponents' win percentage for team: Wauwatosa West
# Calculating opponents' opponents' win percentage for team: Wauzeka-Steuben
# Calculating opponents' opponents' win percentage for team: Wayland Academy
# Calculating opponents' opponents' win percentage for team: Webster
# Calculating opponents' opponents' win percentage for team: West Allis Central
# Calculating opponents' opponents' win percentage for team: West Allis Hale
# Calculating opponents' opponents' win percentage for team: West Bend East
# Calculating opponents' opponents' win percentage for team: West Bend West
# Calculating opponents' opponents' win percentage for team: West De Pere
# Calculating opponents' opponents' win percentage for team: West Salem
# Calculating opponents' opponents' win percentage for team: Westby
# Calculating opponents' opponents' win percentage for team: Westfield
# Calculating opponents' opponents' win percentage for team: Weston
# Calculating opponents' opponents' win percentage for team: Westosha Central
# Calculating opponents' opponents' win percentage for team: Weyauwega-Fremont
# Calculating opponents' opponents' win percentage for team: White Lake
# Calculating opponents' opponents' win percentage for team: Whitefish Bay
# Calculating opponents' opponents' win percentage for team: Whitehall
# Calculating opponents' opponents' win percentage for team: Whitewater
# Calculating opponents' opponents' win percentage for team: Whitnall
# Calculating opponents' opponents' win percentage for team: Wild Rose
# Calculating opponents' opponents' win percentage for team: Williams Bay
# Calculating opponents' opponents' win percentage for team: Wilmot
# Calculating opponents' opponents' win percentage for team: Winnebago Lutheran
# Calculating opponents' opponents' win percentage for team: Winneconne
# Calculating opponents' opponents' win percentage for team: Winter
# Calculating opponents' opponents' win percentage for team: Wisconsin Dells
# Calculating opponents' opponents' win percentage for team: Wisconsin Heights
# Calculating opponents' opponents' win percentage for team: Wisconsin Lutheran
# Calculating opponents' opponents' win percentage for team: Wisconsin Rapids Lincoln
# Calculating opponents' opponents' win percentage for team: Wittenberg-Birnamwood
# Calculating opponents' opponents' win percentage for team: Wonewoc-Center
# Calculating opponents' opponents' win percentage for team: Wrightstown
# Calculating opponents' opponents' win percentage for team: Xavier
# Calculating opponents' opponents' win percentage for team: Young Coggs
#                                   Team  \
# 0                           Abbotsford
# 1  Abundant Life Christian/St. Ambrose
# 2                     Adams-Friendship
# 3                    Albany/Monticello
# 4                               Algoma
#
#                                           Game_Dates  \
# 0  [2023-11-16 00:00:00, 2023-11-20 00:00:00, 202...
# 1  [2023-11-14 00:00:00, 2023-11-16 00:00:00, 202...
# 2  [2023-11-14 00:00:00, 2023-11-16 00:00:00, 202...
# 3  [2023-11-14 00:00:00, 2023-11-16 00:00:00, 202...
# 4  [2023-11-14 00:00:00, 2023-11-16 00:00:00, 202...
#
#                                         Teams_Played  \
# 0  [Athens, Colby, Prentice, Greenwood, Auburndal...
# 1  [Juda, Central WI Christian, Parkview, Argyle/...
# 2  [Cambridge, Poynette, Marshall, Amherst, Tomah...
# 3  [Benton, Turner, Belleville, Williams Bay, Bel...
# 4  [Bonduel, Freedom, Mishicot, Green Bay N.E.W. ...
#
#                                                  Win  \
# 0  [False, True, False, False, False, True, True,...
# 1  [True, True, True, False, True, True, False, T...
# 2  [False, False, False, False, False, False, Tru...
# 3  [True, True, True, True, True, True, True, Tru...
# 4  [False, False, False, True, False, True, False...
#
#                                           Points_For  \
# 0  [42.0, 69.0, 36.0, 47.0, 28.0, 52.0, 45.0, 46....
# 1  [63.0, 45.0, 52.0, 39.0, 61.0, 57.0, 34.0, 69....
# 2  [34.0, 50.0, 36.0, 30.0, 40.0, 44.0, 63.0, 62....
# 3  [73.0, 47.0, 55.0, 72.0, 69.0, 68.0, 90.0, 81....
# 4  [22.0, 27.0, 40.0, 64.0, 32.0, 51.0, 30.0, 56....
#
#                                       Points_Against  \
# 0  [64.0, 29.0, 43.0, 48.0, 35.0, 39.0, 30.0, 40....
# 1  [25.0, 28.0, 26.0, 73.0, 4.0, 29.0, 55.0, 33.0...
# 2  [65.0, 53.0, 45.0, 38.0, 54.0, 49.0, 32.0, 71....
# 3  [26.0, 29.0, 37.0, 18.0, 56.0, 38.0, 20.0, 15....
# 4  [45.0, 48.0, 48.0, 36.0, 45.0, 28.0, 37.0, 41....
#
#                                            Seed_Game  \
# 0  [True, True, True, True, True, True, True, Tru...
# 1  [True, True, True, True, True, True, True, Tru...
# 2  [True, True, True, True, True, True, True, Tru...
# 3  [True, True, True, True, True, True, True, Tru...
# 4  [True, True, True, True, True, True, True, Tru...
#
#                                         Tourney_Game   wp% Wins  ...  \
# 0  [False, False, False, False, False, False, Fal...  None   10  ...
# 1  [False, False, False, False, False, False, Fal...  None   16  ...
# 2  [False, False, False, False, False, False, Fal...  None    4  ...
# 3  [False, False, False, False, False, False, Fal...  None   20  ...
# 4  [False, False, False, False, False, False, Fal...  None   12  ...
#
#   Defeated_Opponent_Wins  Defeated_Opponent_Losses       ow%      dow%  \
# 0                   78.0                     141.0  0.516269  0.356164
# 1                   97.0                     209.0  0.407229  0.316993
# 2                   23.0                      64.0  0.575937  0.264368
# 3                  165.0                     253.0  0.459459  0.394737
# 4                   74.0                     186.0  0.482180  0.284615
#
#    Opponent_Opponent_Wins  Opponent_Opponent_Losses  \
# 0                  4819.0                    4731.0
# 1                  3603.0                    3543.0
# 2                  5145.0                    5519.0
# 3                  4785.0                    4607.0
# 4                  4174.0                    4322.0
#
#    Defeated_Opponent_Opponent_Wins  Defeated_Opponent_Opponent_Losses  \
# 0                           2144.0                             2150.0
# 1                           2449.0                             2419.0
# 2                            756.0                              708.0
# 3                           4125.0                             3915.0
# 4                           2144.0                             2099.0
#
#        oow%     doow%
# 0  0.504607  0.499301
# 1  0.504198  0.503081
# 2  0.482464  0.516393
# 3  0.509476  0.513060
# 4  0.491290  0.505303
#
# [5 rows x 24 columns]

# %%
input_data = return_winning_percentage_dfs(df=wp_owp_24_sgo, year=2024)
input_data.head()
# Out:
#                                   Team  Division Sectional  Seed    Year  \
# 0                           Abbotsford       4.0        1B   5.0  2024.0
# 1  Abundant Life Christian/St. Ambrose       4.0        4B   5.0  2024.0
# 2                     Adams-Friendship       3.0        1B   9.0  2024.0
# 3                    Albany/Monticello       5.0        4B   1.0  2024.0
# 4                               Algoma       4.0        2B   6.0  2024.0
#
#          w%       ow%      oow%      dow%     doow%
# 0  0.476190  0.516269  0.504607  0.356164  0.499301
# 1  0.761905  0.407229  0.504198  0.316993  0.503081
# 2  0.173913  0.575937  0.482464  0.264368  0.516393
# 3  0.869565  0.459459  0.509476  0.394737  0.513060
# 4  0.545455  0.482180  0.491290  0.284615  0.505303

# %%
input_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 482 entries, 0 to 481
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Team       482 non-null    object
#  1   Division   458 non-null    float64
#  2   Sectional  458 non-null    object
#  3   Seed       458 non-null    float64
#  4   Year       458 non-null    float64
#  5   w%         481 non-null    float64
#  6   ow%        470 non-null    float64
#  7   oow%       470 non-null    float64
#  8   dow%       454 non-null    float64
#  9   doow%      453 non-null    float64
# dtypes: float64(8), object(2)
# memory usage: 37.8+ KB

# %% [markdown]
# Okay, we found out that the issues with the defeated opponents winning percentages were that these teams did not win games. The remaining teams are instances where the teams did not play in the 2023-24 season.

# %%
# Overwrite the columns with null winning percentages with zeroes
input_data["ow%"][input_data["ow%"].isnull()] = 0.
input_data["oow%"][input_data["oow%"].isnull()] = 0.
input_data["dow%"][input_data["dow%"].isnull()] = 0.
input_data["doow%"][input_data["doow%"].isnull()] = 0.

# %%
input_data.to_excel("/Users/edebroux/Documents/GHS Basketball/gibraltar_basketball/wiaaWebscrape/wiaa_model_inputs_2024.xlsx", index=False)
#input_data.to_excel("/Users/edebroux/Documents/GHS Basketball/gibraltar_basketball/wiaaWebscrape/wiaa_model_inputs_2024_no_def_oos.xlsx", index=False)
